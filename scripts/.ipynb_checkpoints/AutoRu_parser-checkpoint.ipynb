# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import requests
from requests.exceptions import HTTPError
import re
import datetime

# %% [markdown]
# # Functions

# %%
# function for writing text between first and last
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
def car_url_parser(url):
    # url - start page for chosing auto
    # parse links to cars
    # example url = 'https://auto.ru/cars/kia/optima/all/?listing=listing'
    
    #extract car name from URL
    carName = find_between_r(url,'cars/','/all').replace('/',' ') 
    
    print('Parsing advertisements pages: Start ' + carName.upper())
    
    # parse links to cars
    
    content = urllib.request.urlopen(url)
    soup = BeautifulSoup(content, "lxml")
    
    # total ammount of cars:
    carsN = float(soup.find('span', class_="tabs__count").text)
    # number of pages with ads
    pageN = int(carsN / 37) + 1
    
    # parsing first page cars urls
    
    # select car advertising boxes
    cars_boxes = []
    cars_table = soup.find('table', class_ = 'listing-list listing listing-wrap__listing i-bem')
    for box in cars_table.find_all('tbody'):
        cars_boxes.append(box)

    # create list of car ads urls
    cars_urls = []
    for box in cars_boxes:
        try:
            if box.find_all('a')[0].get('href')[0:10] == '//auto.ru/':
                cars_urls.append(box.find_all('a')[0].get('href'))
        except:
            continue
    
    
    print('--Parsing advertising pages ' + \
    ' %.1f%% (%d/%d)' % (float(1) / float(pageN) * 100, 1, pageN))
    
    # parsing all pages 
    for page in range(2, pageN + 1):
        try:
            url_temp = url + "&page_num_offers=%d" % page
            r = requests.get(url_temp)
            r.raise_for_status()                    
            content = urllib.request.urlopen(url_temp)
            soup = BeautifulSoup(content, "lxml")
            # select car advertising boxes
            cars_boxes = []
            cars_table = soup.find('table', class_ = 'listing-list listing listing-wrap__listing i-bem')
            for box in cars_table.find_all('tbody'):
                cars_boxes.append(box)

            # add car ads urls to list
            for box in cars_boxes:
                try:
                    if box.find_all('a')[0].get('href')[0:10] == '//auto.ru/':
                        cars_urls.append(box.find_all('a')[0].get('href'))
                except:
                    continue      
            print('--Parsing advertising pages '  + \
            ' %.1f%% (%d/%d)' % (float(page) / float(pageN) * 100, page , pageN))
        except HTTPError:
            continue
            
    # remove duplicates
    cars_urls = list(set(cars_urls))
    print('Parsing advertisements pages: End '+ carName.upper())
    return cars_urls

# %%
def car_parser(url_list, base_url, log_save_path):

    # url_list - лист со ссылками на сраницы с машинами на avto.ru
    # base_url - ссылка на 1 страницу объявлений
    
    carName = find_between_r(base_url,'cars/','/all').replace('/',' ')
    print('---Parsing advertisements Start: ' + carName.upper())
    #лист в котором будут хратиться данные о машинах
    cars = []
    now = str(datetime.datetime.now())[:10]
    
    problem_pages = []
    #цикл по страницам машин
    i = 1 
    for ad_url in url_list:
        url = 'https:' + ad_url
        if i%10 == 0:
            print('-----Parsing advertisements: ' + carName.upper() + 
                  ' %.1f%% (%d/%d)' %  (float(i) / float(len(url_list)) * 100, i, len(url_list)))
        try:
            content = urllib.request.urlopen(url)
            soup = BeautifulSoup(content, "lxml")
            
            #dictionary with ad params
            car = {}
            
            car['Parsing date'] = now
            car['URL'] = url
            car['Brand'] = soup.find('h1', class_ = 'card__title').get('title')[8:]
            
            #upper head of advertisment
            head = []
            for x in soup.find_all('li', class_ = 'card__stat-item'):
                head.append(x.get_text())
            car['ID'] = re.sub('[^0-9]','',head[0])
            car['Add date'] = head[1][10:]
            car['Views'] =  re.sub('[^0-9]','',head[2])
            
            price = soup.find('h4', class_ = 'card__price-rur').get_text()
            car['Price_rub'] = re.sub('[^0-9]','',price)
            
            seller = soup.find('dd', class_ = 'card__contact-value').get_text()
            car['Seller'] = seller[:seller.index('Написать продавцу')]
            car['Seller_location'] = soup.find('div', class_ = 'sale-location__title').get_text()
            
            #left table
            
            left_table_name = []
            left_table_param = []
            ii = 1
            for dt in soup.find('dl', class_ = 'card__info'):
                if ii%2 == 1:
                    left_table_name.append(dt.get_text())
                else:
                    left_table_param.append(dt.get_text())
                ii += 1
            left_table_dict = dict(zip(left_table_name,left_table_param))
            car = dict(car, **left_table_dict)
            
            #bottom table
            if soup.find('div', class_ = 'seller-details__text') == None:
                car['comment'] = ''
            else:
                car['comment'] = soup.find('div', class_ = 'seller-details__text').get_text()
                
            if soup.find('div', class_ = 'card__package') == None:
                car['complectation'] = ''
            else:
                items = soup.find_all('li', class_ = 'card__package-item')
                car_items = []
                for item in items:
                    car_items.append(item.get_text())
                car['complectation'] = car_items
                
            # add car dictionary to list   
            cars.append(car)    
        except:
            print('Error with advertisement: ' + url)
            problem_pages.append(url)
        i = i + 1
        
    #write errors log file
    with open(log_save_path + 'errors log '+ now + ' ' + carName + '.txt', 'w') as f:
        for page in problem_pages:
            f.write(page + '\n')
            
    print('---Parsing advertisements End: ' + carName.upper())
    return pd.DataFrame(cars)

# %%
def main_parser(start_url_list, save_directory):
    #start_url_list = ['https://auto.ru/cars/kia/optima/all/?listing=listing' - car start page
    
    for url in start_url_list:    
        import datetime
        #базовый url
        #url = 'http://auto.ru/cars/kia/optima/all/'
        startTime = datetime.datetime.now()
        #парсинг ссылок на страницы объявлиний
        url_list = car_url_parser(url)
        #url_list_test = url_list[3000:3300]
        #парсинг объявлений по ссылкам 
        startTime1 = datetime.datetime.now()
        df_cars = car_parser(url_list, url, save_directory)
        
        #сохранение в файл
        
        now = datetime.datetime.now()
        carName = find_between_r(url,'cars/','/all').replace('/','_')
        carName = carName + '_' + str(now)[:10] + '.pickle'
        carName = carName.replace(' ','-').replace(':','_').replace('-','_')
        path = save_directory + carName
        
        print('--Saving File to ' + path)
        df_cars.to_pickle(path)
        print('Done')
        print('===')
        print('===')
        
        #статистика
        TimeElapsed1 = datetime.datetime.now() - startTime1
        TimeElapsed = datetime.datetime.now() - startTime
        print('Full parsing time: ' + str(TimeElapsed))
        print('Total number of advertisements parsed: ' + str(len(df_cars)))
        print('Average parsing time per advertisement: ' + str(TimeElapsed1 / len(df_cars)))
        print('===')
        print('===')

# %% [markdown]
# # Parsing D-class automobiles

# %%
start_urls = ['https://auto.ru/cars/kia/optima/all/?listing=listing', 
              'https://auto.ru/cars/honda/accord/all/?listing=listing',
             'https://auto.ru/cars/hyundai/i40/all/?listing=listing',
             'https://auto.ru/cars/toyota/camry/all/?listing=listing',
             'https://auto.ru/cars/hyundai/sonata/all/?listing=listing',
             'https://auto.ru/cars/mazda/6/all/?listing=listing',
             'https://auto.ru/cars/bmw/5er/all/?listing=listing',
             'https://auto.ru/cars/audi/a6/all/?listing=listing',
             'https://auto.ru/cars/ford/mondeo/all/?listing=listing',
             'https://auto.ru/cars/infiniti/g35/all/?listing=listing',
             'https://auto.ru/cars/nissan/teana/all/?listing=listing',
             'https://auto.ru/cars/opel/insignia/all/?listing=listing',
             'https://auto.ru/cars/volvo/s60/all/?listing=listing']

save_dir = 'C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/'
#save_dir = 'C:/Users/Vasily/Google Диск/analytics/auto_ru/data/'

# %%
main_parser(start_url_list = start_urls, save_directory=save_dir)
# Out:
# Parsing advertisements pages: Start KIA OPTIMA
# --Parsing advertising pages  16.7% (1/6)
# --Parsing advertising pages  33.3% (2/6)
# --Parsing advertising pages  50.0% (3/6)
# --Parsing advertising pages  66.7% (4/6)
# --Parsing advertising pages  83.3% (5/6)
# --Parsing advertising pages  100.0% (6/6)
# Parsing advertisements pages: End KIA OPTIMA
# ---Parsing advertisements Start: KIA OPTIMA
# -----Parsing advertisements: KIA OPTIMA 4.7% (10/213)
# Error with advertisement: https://auto.ru/cars/used/sale/1034979175-4c44/
# -----Parsing advertisements: KIA OPTIMA 9.4% (20/213)
# -----Parsing advertisements: KIA OPTIMA 14.1% (30/213)
# -----Parsing advertisements: KIA OPTIMA 18.8% (40/213)
# -----Parsing advertisements: KIA OPTIMA 23.5% (50/213)
# -----Parsing advertisements: KIA OPTIMA 28.2% (60/213)
# -----Parsing advertisements: KIA OPTIMA 32.9% (70/213)
# Error with advertisement: https://auto.ru/cars/used/sale/1032916839-d733/
# -----Parsing advertisements: KIA OPTIMA 37.6% (80/213)
# -----Parsing advertisements: KIA OPTIMA 42.3% (90/213)
# -----Parsing advertisements: KIA OPTIMA 46.9% (100/213)
# -----Parsing advertisements: KIA OPTIMA 51.6% (110/213)
# -----Parsing advertisements: KIA OPTIMA 56.3% (120/213)
# -----Parsing advertisements: KIA OPTIMA 61.0% (130/213)
# -----Parsing advertisements: KIA OPTIMA 65.7% (140/213)
# Error with advertisement: https://auto.ru/cars/used/sale/1033110125-e72b/
# -----Parsing advertisements: KIA OPTIMA 70.4% (150/213)
# -----Parsing advertisements: KIA OPTIMA 75.1% (160/213)
# -----Parsing advertisements: KIA OPTIMA 79.8% (170/213)
# -----Parsing advertisements: KIA OPTIMA 84.5% (180/213)
# -----Parsing advertisements: KIA OPTIMA 89.2% (190/213)
# -----Parsing advertisements: KIA OPTIMA 93.9% (200/213)
# -----Parsing advertisements: KIA OPTIMA 98.6% (210/213)
# ---Parsing advertisements End: KIA OPTIMA
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/kia_optima_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:03:40.990405
# Total number of advertisements parsed: 210
# Average parsing time per advertisement: 0:00:01.008151
# ===
# ===
# Parsing advertisements pages: Start HONDA ACCORD
# --Parsing advertising pages  5.3% (1/19)
# --Parsing advertising pages  10.5% (2/19)
# --Parsing advertising pages  15.8% (3/19)
# --Parsing advertising pages  21.1% (4/19)
# --Parsing advertising pages  26.3% (5/19)
# --Parsing advertising pages  31.6% (6/19)
# --Parsing advertising pages  36.8% (7/19)
# --Parsing advertising pages  42.1% (8/19)
# --Parsing advertising pages  47.4% (9/19)
# --Parsing advertising pages  52.6% (10/19)
# --Parsing advertising pages  57.9% (11/19)
# --Parsing advertising pages  63.2% (12/19)
# --Parsing advertising pages  68.4% (13/19)
# --Parsing advertising pages  73.7% (14/19)
# --Parsing advertising pages  78.9% (15/19)
# --Parsing advertising pages  84.2% (16/19)
# --Parsing advertising pages  89.5% (17/19)
# --Parsing advertising pages  94.7% (18/19)
# --Parsing advertising pages  100.0% (19/19)
# Parsing advertisements pages: End HONDA ACCORD
# ---Parsing advertisements Start: HONDA ACCORD
# -----Parsing advertisements: HONDA ACCORD 1.5% (10/673)
# -----Parsing advertisements: HONDA ACCORD 3.0% (20/673)
# -----Parsing advertisements: HONDA ACCORD 4.5% (30/673)
# -----Parsing advertisements: HONDA ACCORD 5.9% (40/673)
# Error with advertisement: https://auto.ru/cars/used/sale/1029623419-214b3a/
# -----Parsing advertisements: HONDA ACCORD 7.4% (50/673)
# -----Parsing advertisements: HONDA ACCORD 8.9% (60/673)
# -----Parsing advertisements: HONDA ACCORD 10.4% (70/673)
# -----Parsing advertisements: HONDA ACCORD 11.9% (80/673)
# Error with advertisement: https://auto.ru/cars/used/sale/1032712945-f626/
# -----Parsing advertisements: HONDA ACCORD 13.4% (90/673)
# -----Parsing advertisements: HONDA ACCORD 14.9% (100/673)
# -----Parsing advertisements: HONDA ACCORD 16.3% (110/673)
# -----Parsing advertisements: HONDA ACCORD 17.8% (120/673)
# -----Parsing advertisements: HONDA ACCORD 19.3% (130/673)
# -----Parsing advertisements: HONDA ACCORD 20.8% (140/673)
# -----Parsing advertisements: HONDA ACCORD 22.3% (150/673)
# -----Parsing advertisements: HONDA ACCORD 23.8% (160/673)
# -----Parsing advertisements: HONDA ACCORD 25.3% (170/673)
# -----Parsing advertisements: HONDA ACCORD 26.7% (180/673)
# -----Parsing advertisements: HONDA ACCORD 28.2% (190/673)
# Error with advertisement: https://auto.ru/cars/used/sale/1030085325-f627b1/
# -----Parsing advertisements: HONDA ACCORD 29.7% (200/673)
# -----Parsing advertisements: HONDA ACCORD 31.2% (210/673)
# -----Parsing advertisements: HONDA ACCORD 32.7% (220/673)
# -----Parsing advertisements: HONDA ACCORD 34.2% (230/673)
# -----Parsing advertisements: HONDA ACCORD 35.7% (240/673)
# -----Parsing advertisements: HONDA ACCORD 37.1% (250/673)
# -----Parsing advertisements: HONDA ACCORD 38.6% (260/673)
# Error with advertisement: https://auto.ru/cars/used/sale/1009156233-826f52/
# -----Parsing advertisements: HONDA ACCORD 40.1% (270/673)
# -----Parsing advertisements: HONDA ACCORD 41.6% (280/673)
# -----Parsing advertisements: HONDA ACCORD 43.1% (290/673)
# -----Parsing advertisements: HONDA ACCORD 44.6% (300/673)
# -----Parsing advertisements: HONDA ACCORD 46.1% (310/673)
# -----Parsing advertisements: HONDA ACCORD 47.5% (320/673)
# -----Parsing advertisements: HONDA ACCORD 49.0% (330/673)
# -----Parsing advertisements: HONDA ACCORD 50.5% (340/673)
# -----Parsing advertisements: HONDA ACCORD 52.0% (350/673)
# -----Parsing advertisements: HONDA ACCORD 53.5% (360/673)
# -----Parsing advertisements: HONDA ACCORD 55.0% (370/673)
# Error with advertisement: https://auto.ru/cars/used/sale/1034455126-0269/
# -----Parsing advertisements: HONDA ACCORD 56.5% (380/673)
# -----Parsing advertisements: HONDA ACCORD 57.9% (390/673)
# -----Parsing advertisements: HONDA ACCORD 59.4% (400/673)
# -----Parsing advertisements: HONDA ACCORD 60.9% (410/673)
# -----Parsing advertisements: HONDA ACCORD 62.4% (420/673)
# -----Parsing advertisements: HONDA ACCORD 63.9% (430/673)
# -----Parsing advertisements: HONDA ACCORD 65.4% (440/673)
# -----Parsing advertisements: HONDA ACCORD 66.9% (450/673)
# -----Parsing advertisements: HONDA ACCORD 68.4% (460/673)
# -----Parsing advertisements: HONDA ACCORD 69.8% (470/673)
# -----Parsing advertisements: HONDA ACCORD 71.3% (480/673)
# -----Parsing advertisements: HONDA ACCORD 72.8% (490/673)
# -----Parsing advertisements: HONDA ACCORD 74.3% (500/673)
# -----Parsing advertisements: HONDA ACCORD 75.8% (510/673)
# -----Parsing advertisements: HONDA ACCORD 77.3% (520/673)
# -----Parsing advertisements: HONDA ACCORD 78.8% (530/673)
# -----Parsing advertisements: HONDA ACCORD 80.2% (540/673)
# -----Parsing advertisements: HONDA ACCORD 81.7% (550/673)
# -----Parsing advertisements: HONDA ACCORD 83.2% (560/673)
# -----Parsing advertisements: HONDA ACCORD 84.7% (570/673)
# -----Parsing advertisements: HONDA ACCORD 86.2% (580/673)
# -----Parsing advertisements: HONDA ACCORD 87.7% (590/673)
# -----Parsing advertisements: HONDA ACCORD 89.2% (600/673)
# -----Parsing advertisements: HONDA ACCORD 90.6% (610/673)
# -----Parsing advertisements: HONDA ACCORD 92.1% (620/673)
# -----Parsing advertisements: HONDA ACCORD 93.6% (630/673)
# -----Parsing advertisements: HONDA ACCORD 95.1% (640/673)
# -----Parsing advertisements: HONDA ACCORD 96.6% (650/673)
# -----Parsing advertisements: HONDA ACCORD 98.1% (660/673)
# -----Parsing advertisements: HONDA ACCORD 99.6% (670/673)
# ---Parsing advertisements End: HONDA ACCORD
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/honda_accord_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:11:49.575904
# Total number of advertisements parsed: 668
# Average parsing time per advertisement: 0:00:01.012913
# ===
# ===
# Parsing advertisements pages: Start HYUNDAI I40
# --Parsing advertising pages  20.0% (1/5)
# --Parsing advertising pages  40.0% (2/5)
# --Parsing advertising pages  60.0% (3/5)
# --Parsing advertising pages  80.0% (4/5)
# --Parsing advertising pages  100.0% (5/5)
# Parsing advertisements pages: End HYUNDAI I40
# ---Parsing advertisements Start: HYUNDAI I40
# -----Parsing advertisements: HYUNDAI I40 6.7% (10/149)
# -----Parsing advertisements: HYUNDAI I40 13.4% (20/149)
# -----Parsing advertisements: HYUNDAI I40 20.1% (30/149)
# -----Parsing advertisements: HYUNDAI I40 26.8% (40/149)
# -----Parsing advertisements: HYUNDAI I40 33.6% (50/149)
# -----Parsing advertisements: HYUNDAI I40 40.3% (60/149)
# -----Parsing advertisements: HYUNDAI I40 47.0% (70/149)
# Error with advertisement: https://auto.ru/cars/new/sale/1034083927-cb87/
# -----Parsing advertisements: HYUNDAI I40 53.7% (80/149)
# -----Parsing advertisements: HYUNDAI I40 60.4% (90/149)
# -----Parsing advertisements: HYUNDAI I40 67.1% (100/149)
# -----Parsing advertisements: HYUNDAI I40 73.8% (110/149)
# -----Parsing advertisements: HYUNDAI I40 80.5% (120/149)
# -----Parsing advertisements: HYUNDAI I40 87.2% (130/149)
# -----Parsing advertisements: HYUNDAI I40 94.0% (140/149)
# Error with advertisement: https://auto.ru/cars/hyundai/i40/
# ---Parsing advertisements End: HYUNDAI I40
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/hyundai_i40_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:02:35.024503
# Total number of advertisements parsed: 147
# Average parsing time per advertisement: 0:00:00.997845
# ===
# ===
# Parsing advertisements pages: Start TOYOTA CAMRY
# --Parsing advertising pages  2.6% (1/39)
# --Parsing advertising pages  5.1% (2/39)
# --Parsing advertising pages  7.7% (3/39)
# --Parsing advertising pages  10.3% (4/39)
# --Parsing advertising pages  12.8% (5/39)
# --Parsing advertising pages  15.4% (6/39)
# --Parsing advertising pages  17.9% (7/39)
# --Parsing advertising pages  20.5% (8/39)
# --Parsing advertising pages  23.1% (9/39)
# --Parsing advertising pages  25.6% (10/39)
# --Parsing advertising pages  28.2% (11/39)
# --Parsing advertising pages  30.8% (12/39)
# --Parsing advertising pages  33.3% (13/39)
# --Parsing advertising pages  35.9% (14/39)
# --Parsing advertising pages  38.5% (15/39)
# --Parsing advertising pages  41.0% (16/39)
# --Parsing advertising pages  43.6% (17/39)
# --Parsing advertising pages  46.2% (18/39)
# --Parsing advertising pages  48.7% (19/39)
# --Parsing advertising pages  51.3% (20/39)
# --Parsing advertising pages  53.8% (21/39)
# --Parsing advertising pages  56.4% (22/39)
# --Parsing advertising pages  59.0% (23/39)
# --Parsing advertising pages  61.5% (24/39)
# --Parsing advertising pages  64.1% (25/39)
# --Parsing advertising pages  66.7% (26/39)
# --Parsing advertising pages  69.2% (27/39)
# --Parsing advertising pages  71.8% (28/39)
# --Parsing advertising pages  74.4% (29/39)
# --Parsing advertising pages  76.9% (30/39)
# --Parsing advertising pages  79.5% (31/39)
# --Parsing advertising pages  82.1% (32/39)
# --Parsing advertising pages  84.6% (33/39)
# --Parsing advertising pages  87.2% (34/39)
# --Parsing advertising pages  89.7% (35/39)
# --Parsing advertising pages  92.3% (36/39)
# --Parsing advertising pages  94.9% (37/39)
# --Parsing advertising pages  97.4% (38/39)
# --Parsing advertising pages  100.0% (39/39)
# Parsing advertisements pages: End TOYOTA CAMRY
# ---Parsing advertisements Start: TOYOTA CAMRY
# -----Parsing advertisements: TOYOTA CAMRY 1.1% (10/924)
# -----Parsing advertisements: TOYOTA CAMRY 2.2% (20/924)
# -----Parsing advertisements: TOYOTA CAMRY 3.2% (30/924)
# -----Parsing advertisements: TOYOTA CAMRY 4.3% (40/924)
# -----Parsing advertisements: TOYOTA CAMRY 5.4% (50/924)
# -----Parsing advertisements: TOYOTA CAMRY 6.5% (60/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1034080045-1d45ce/
# -----Parsing advertisements: TOYOTA CAMRY 7.6% (70/924)
# -----Parsing advertisements: TOYOTA CAMRY 8.7% (80/924)
# -----Parsing advertisements: TOYOTA CAMRY 9.7% (90/924)
# -----Parsing advertisements: TOYOTA CAMRY 10.8% (100/924)
# -----Parsing advertisements: TOYOTA CAMRY 11.9% (110/924)
# -----Parsing advertisements: TOYOTA CAMRY 13.0% (120/924)
# -----Parsing advertisements: TOYOTA CAMRY 14.1% (130/924)
# -----Parsing advertisements: TOYOTA CAMRY 15.2% (140/924)
# -----Parsing advertisements: TOYOTA CAMRY 16.2% (150/924)
# -----Parsing advertisements: TOYOTA CAMRY 17.3% (160/924)
# -----Parsing advertisements: TOYOTA CAMRY 18.4% (170/924)
# -----Parsing advertisements: TOYOTA CAMRY 19.5% (180/924)
# -----Parsing advertisements: TOYOTA CAMRY 20.6% (190/924)
# -----Parsing advertisements: TOYOTA CAMRY 21.6% (200/924)
# -----Parsing advertisements: TOYOTA CAMRY 22.7% (210/924)
# -----Parsing advertisements: TOYOTA CAMRY 23.8% (220/924)
# -----Parsing advertisements: TOYOTA CAMRY 24.9% (230/924)
# -----Parsing advertisements: TOYOTA CAMRY 26.0% (240/924)
# -----Parsing advertisements: TOYOTA CAMRY 27.1% (250/924)
# -----Parsing advertisements: TOYOTA CAMRY 28.1% (260/924)
# -----Parsing advertisements: TOYOTA CAMRY 29.2% (270/924)
# -----Parsing advertisements: TOYOTA CAMRY 30.3% (280/924)
# -----Parsing advertisements: TOYOTA CAMRY 31.4% (290/924)
# -----Parsing advertisements: TOYOTA CAMRY 32.5% (300/924)
# -----Parsing advertisements: TOYOTA CAMRY 33.5% (310/924)
# -----Parsing advertisements: TOYOTA CAMRY 34.6% (320/924)
# -----Parsing advertisements: TOYOTA CAMRY 35.7% (330/924)
# -----Parsing advertisements: TOYOTA CAMRY 36.8% (340/924)
# -----Parsing advertisements: TOYOTA CAMRY 37.9% (350/924)
# -----Parsing advertisements: TOYOTA CAMRY 39.0% (360/924)
# -----Parsing advertisements: TOYOTA CAMRY 40.0% (370/924)
# -----Parsing advertisements: TOYOTA CAMRY 41.1% (380/924)
# -----Parsing advertisements: TOYOTA CAMRY 42.2% (390/924)
# -----Parsing advertisements: TOYOTA CAMRY 43.3% (400/924)
# -----Parsing advertisements: TOYOTA CAMRY 44.4% (410/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1034056175-3ce9/
# -----Parsing advertisements: TOYOTA CAMRY 45.5% (420/924)
# -----Parsing advertisements: TOYOTA CAMRY 46.5% (430/924)
# -----Parsing advertisements: TOYOTA CAMRY 47.6% (440/924)
# -----Parsing advertisements: TOYOTA CAMRY 48.7% (450/924)
# -----Parsing advertisements: TOYOTA CAMRY 49.8% (460/924)
# -----Parsing advertisements: TOYOTA CAMRY 50.9% (470/924)
# -----Parsing advertisements: TOYOTA CAMRY 51.9% (480/924)
# -----Parsing advertisements: TOYOTA CAMRY 53.0% (490/924)
# -----Parsing advertisements: TOYOTA CAMRY 54.1% (500/924)
# -----Parsing advertisements: TOYOTA CAMRY 55.2% (510/924)
# -----Parsing advertisements: TOYOTA CAMRY 56.3% (520/924)
# -----Parsing advertisements: TOYOTA CAMRY 57.4% (530/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1033913811-e617c/
# -----Parsing advertisements: TOYOTA CAMRY 58.4% (540/924)
# -----Parsing advertisements: TOYOTA CAMRY 59.5% (550/924)
# -----Parsing advertisements: TOYOTA CAMRY 60.6% (560/924)
# -----Parsing advertisements: TOYOTA CAMRY 61.7% (570/924)
# -----Parsing advertisements: TOYOTA CAMRY 62.8% (580/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1033333875-472d8/
# -----Parsing advertisements: TOYOTA CAMRY 63.9% (590/924)
# -----Parsing advertisements: TOYOTA CAMRY 64.9% (600/924)
# -----Parsing advertisements: TOYOTA CAMRY 66.0% (610/924)
# -----Parsing advertisements: TOYOTA CAMRY 67.1% (620/924)
# -----Parsing advertisements: TOYOTA CAMRY 68.2% (630/924)
# -----Parsing advertisements: TOYOTA CAMRY 69.3% (640/924)
# -----Parsing advertisements: TOYOTA CAMRY 70.3% (650/924)
# -----Parsing advertisements: TOYOTA CAMRY 71.4% (660/924)
# -----Parsing advertisements: TOYOTA CAMRY 72.5% (670/924)
# -----Parsing advertisements: TOYOTA CAMRY 73.6% (680/924)
# -----Parsing advertisements: TOYOTA CAMRY 74.7% (690/924)
# -----Parsing advertisements: TOYOTA CAMRY 75.8% (700/924)
# -----Parsing advertisements: TOYOTA CAMRY 76.8% (710/924)
# -----Parsing advertisements: TOYOTA CAMRY 77.9% (720/924)
# -----Parsing advertisements: TOYOTA CAMRY 79.0% (730/924)
# -----Parsing advertisements: TOYOTA CAMRY 80.1% (740/924)
# -----Parsing advertisements: TOYOTA CAMRY 81.2% (750/924)
# -----Parsing advertisements: TOYOTA CAMRY 82.3% (760/924)
# -----Parsing advertisements: TOYOTA CAMRY 83.3% (770/924)
# -----Parsing advertisements: TOYOTA CAMRY 84.4% (780/924)
# -----Parsing advertisements: TOYOTA CAMRY 85.5% (790/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1033929485-9c5db/
# -----Parsing advertisements: TOYOTA CAMRY 86.6% (800/924)
# Error with advertisement: https://auto.ru/cars/used/sale/1033624703-c401d/
# -----Parsing advertisements: TOYOTA CAMRY 87.7% (810/924)
# -----Parsing advertisements: TOYOTA CAMRY 88.7% (820/924)
# -----Parsing advertisements: TOYOTA CAMRY 89.8% (830/924)
# -----Parsing advertisements: TOYOTA CAMRY 90.9% (840/924)
# -----Parsing advertisements: TOYOTA CAMRY 92.0% (850/924)
# -----Parsing advertisements: TOYOTA CAMRY 93.1% (860/924)
# -----Parsing advertisements: TOYOTA CAMRY 94.2% (870/924)
# -----Parsing advertisements: TOYOTA CAMRY 95.2% (880/924)
# -----Parsing advertisements: TOYOTA CAMRY 96.3% (890/924)
# -----Parsing advertisements: TOYOTA CAMRY 97.4% (900/924)
# -----Parsing advertisements: TOYOTA CAMRY 98.5% (910/924)
# -----Parsing advertisements: TOYOTA CAMRY 99.6% (920/924)
# ---Parsing advertisements End: TOYOTA CAMRY
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/toyota_camry_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:16:56.433380
# Total number of advertisements parsed: 918
# Average parsing time per advertisement: 0:00:01.028861
# ===
# ===
# Parsing advertisements pages: Start HYUNDAI SONATA
# --Parsing advertising pages  7.7% (1/13)
# --Parsing advertising pages  15.4% (2/13)
# --Parsing advertising pages  23.1% (3/13)
# --Parsing advertising pages  30.8% (4/13)
# --Parsing advertising pages  38.5% (5/13)
# --Parsing advertising pages  46.2% (6/13)
# --Parsing advertising pages  53.8% (7/13)
# --Parsing advertising pages  61.5% (8/13)
# --Parsing advertising pages  69.2% (9/13)
# --Parsing advertising pages  76.9% (10/13)
# --Parsing advertising pages  84.6% (11/13)
# --Parsing advertising pages  92.3% (12/13)
# --Parsing advertising pages  100.0% (13/13)
# Parsing advertisements pages: End HYUNDAI SONATA
# ---Parsing advertisements Start: HYUNDAI SONATA
# -----Parsing advertisements: HYUNDAI SONATA 2.2% (10/447)
# -----Parsing advertisements: HYUNDAI SONATA 4.5% (20/447)
# -----Parsing advertisements: HYUNDAI SONATA 6.7% (30/447)
# -----Parsing advertisements: HYUNDAI SONATA 8.9% (40/447)
# -----Parsing advertisements: HYUNDAI SONATA 11.2% (50/447)
# -----Parsing advertisements: HYUNDAI SONATA 13.4% (60/447)
# -----Parsing advertisements: HYUNDAI SONATA 15.7% (70/447)
# -----Parsing advertisements: HYUNDAI SONATA 17.9% (80/447)
# Error with advertisement: https://auto.ru/cars/used/sale/1034058569-04dff7/
# -----Parsing advertisements: HYUNDAI SONATA 20.1% (90/447)
# -----Parsing advertisements: HYUNDAI SONATA 22.4% (100/447)
# -----Parsing advertisements: HYUNDAI SONATA 24.6% (110/447)
# -----Parsing advertisements: HYUNDAI SONATA 26.8% (120/447)
# -----Parsing advertisements: HYUNDAI SONATA 29.1% (130/447)
# -----Parsing advertisements: HYUNDAI SONATA 31.3% (140/447)
# -----Parsing advertisements: HYUNDAI SONATA 33.6% (150/447)
# -----Parsing advertisements: HYUNDAI SONATA 35.8% (160/447)
# -----Parsing advertisements: HYUNDAI SONATA 38.0% (170/447)
# -----Parsing advertisements: HYUNDAI SONATA 40.3% (180/447)
# -----Parsing advertisements: HYUNDAI SONATA 42.5% (190/447)
# -----Parsing advertisements: HYUNDAI SONATA 44.7% (200/447)
# -----Parsing advertisements: HYUNDAI SONATA 47.0% (210/447)
# -----Parsing advertisements: HYUNDAI SONATA 49.2% (220/447)
# -----Parsing advertisements: HYUNDAI SONATA 51.5% (230/447)
# -----Parsing advertisements: HYUNDAI SONATA 53.7% (240/447)
# -----Parsing advertisements: HYUNDAI SONATA 55.9% (250/447)
# -----Parsing advertisements: HYUNDAI SONATA 58.2% (260/447)
# -----Parsing advertisements: HYUNDAI SONATA 60.4% (270/447)
# Error with advertisement: https://auto.ru/cars/used/sale/1035011961-51fb0/
# -----Parsing advertisements: HYUNDAI SONATA 62.6% (280/447)
# -----Parsing advertisements: HYUNDAI SONATA 64.9% (290/447)
# -----Parsing advertisements: HYUNDAI SONATA 67.1% (300/447)
# -----Parsing advertisements: HYUNDAI SONATA 69.4% (310/447)
# -----Parsing advertisements: HYUNDAI SONATA 71.6% (320/447)
# -----Parsing advertisements: HYUNDAI SONATA 73.8% (330/447)
# -----Parsing advertisements: HYUNDAI SONATA 76.1% (340/447)
# -----Parsing advertisements: HYUNDAI SONATA 78.3% (350/447)
# -----Parsing advertisements: HYUNDAI SONATA 80.5% (360/447)
# -----Parsing advertisements: HYUNDAI SONATA 82.8% (370/447)
# -----Parsing advertisements: HYUNDAI SONATA 85.0% (380/447)
# -----Parsing advertisements: HYUNDAI SONATA 87.2% (390/447)
# -----Parsing advertisements: HYUNDAI SONATA 89.5% (400/447)
# -----Parsing advertisements: HYUNDAI SONATA 91.7% (410/447)
# Error with advertisement: https://auto.ru/cars/used/sale/1032832653-c039b/
# -----Parsing advertisements: HYUNDAI SONATA 94.0% (420/447)
# -----Parsing advertisements: HYUNDAI SONATA 96.2% (430/447)
# -----Parsing advertisements: HYUNDAI SONATA 98.4% (440/447)
# ---Parsing advertisements End: HYUNDAI SONATA
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/hyundai_sonata_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:08:00.398152
# Total number of advertisements parsed: 444
# Average parsing time per advertisement: 0:00:01.028475
# ===
# ===
# Parsing advertisements pages: Start MAZDA 6
# --Parsing advertising pages  3.7% (1/27)
# --Parsing advertising pages  7.4% (2/27)
# --Parsing advertising pages  11.1% (3/27)
# --Parsing advertising pages  14.8% (4/27)
# --Parsing advertising pages  18.5% (5/27)
# --Parsing advertising pages  22.2% (6/27)
# --Parsing advertising pages  25.9% (7/27)
# --Parsing advertising pages  29.6% (8/27)
# --Parsing advertising pages  33.3% (9/27)
# --Parsing advertising pages  37.0% (10/27)
# --Parsing advertising pages  40.7% (11/27)
# --Parsing advertising pages  44.4% (12/27)
# --Parsing advertising pages  48.1% (13/27)
# --Parsing advertising pages  51.9% (14/27)
# --Parsing advertising pages  55.6% (15/27)
# --Parsing advertising pages  59.3% (16/27)
# --Parsing advertising pages  63.0% (17/27)
# --Parsing advertising pages  66.7% (18/27)
# --Parsing advertising pages  70.4% (19/27)
# --Parsing advertising pages  74.1% (20/27)
# --Parsing advertising pages  77.8% (21/27)
# --Parsing advertising pages  81.5% (22/27)
# --Parsing advertising pages  85.2% (23/27)
# --Parsing advertising pages  88.9% (24/27)
# --Parsing advertising pages  92.6% (25/27)
# --Parsing advertising pages  96.3% (26/27)
# --Parsing advertising pages  100.0% (27/27)
# Parsing advertisements pages: End MAZDA 6
# ---Parsing advertisements Start: MAZDA 6
# -----Parsing advertisements: MAZDA 6 1.1% (10/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033575361-aa292d/
# -----Parsing advertisements: MAZDA 6 2.2% (20/923)
# -----Parsing advertisements: MAZDA 6 3.3% (30/923)
# -----Parsing advertisements: MAZDA 6 4.3% (40/923)
# -----Parsing advertisements: MAZDA 6 5.4% (50/923)
# -----Parsing advertisements: MAZDA 6 6.5% (60/923)
# -----Parsing advertisements: MAZDA 6 7.6% (70/923)
# -----Parsing advertisements: MAZDA 6 8.7% (80/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1032363223-b2ec7a/
# -----Parsing advertisements: MAZDA 6 9.8% (90/923)
# -----Parsing advertisements: MAZDA 6 10.8% (100/923)
# -----Parsing advertisements: MAZDA 6 11.9% (110/923)
# -----Parsing advertisements: MAZDA 6 13.0% (120/923)
# -----Parsing advertisements: MAZDA 6 14.1% (130/923)
# -----Parsing advertisements: MAZDA 6 15.2% (140/923)
# -----Parsing advertisements: MAZDA 6 16.3% (150/923)
# -----Parsing advertisements: MAZDA 6 17.3% (160/923)
# -----Parsing advertisements: MAZDA 6 18.4% (170/923)
# -----Parsing advertisements: MAZDA 6 19.5% (180/923)
# -----Parsing advertisements: MAZDA 6 20.6% (190/923)
# -----Parsing advertisements: MAZDA 6 21.7% (200/923)
# -----Parsing advertisements: MAZDA 6 22.8% (210/923)
# -----Parsing advertisements: MAZDA 6 23.8% (220/923)
# -----Parsing advertisements: MAZDA 6 24.9% (230/923)
# -----Parsing advertisements: MAZDA 6 26.0% (240/923)
# -----Parsing advertisements: MAZDA 6 27.1% (250/923)
# -----Parsing advertisements: MAZDA 6 28.2% (260/923)
# -----Parsing advertisements: MAZDA 6 29.3% (270/923)
# -----Parsing advertisements: MAZDA 6 30.3% (280/923)
# -----Parsing advertisements: MAZDA 6 31.4% (290/923)
# -----Parsing advertisements: MAZDA 6 32.5% (300/923)
# -----Parsing advertisements: MAZDA 6 33.6% (310/923)
# -----Parsing advertisements: MAZDA 6 34.7% (320/923)
# -----Parsing advertisements: MAZDA 6 35.8% (330/923)
# -----Parsing advertisements: MAZDA 6 36.8% (340/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033644931-3195/
# -----Parsing advertisements: MAZDA 6 37.9% (350/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1030775253-d8c4cb/
# -----Parsing advertisements: MAZDA 6 39.0% (360/923)
# -----Parsing advertisements: MAZDA 6 40.1% (370/923)
# -----Parsing advertisements: MAZDA 6 41.2% (380/923)
# -----Parsing advertisements: MAZDA 6 42.3% (390/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033647861-f2eea2/
# -----Parsing advertisements: MAZDA 6 43.3% (400/923)
# -----Parsing advertisements: MAZDA 6 44.4% (410/923)
# -----Parsing advertisements: MAZDA 6 45.5% (420/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033915675-309c/
# -----Parsing advertisements: MAZDA 6 46.6% (430/923)
# -----Parsing advertisements: MAZDA 6 47.7% (440/923)
# -----Parsing advertisements: MAZDA 6 48.8% (450/923)
# -----Parsing advertisements: MAZDA 6 49.8% (460/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033501903-45cb/
# -----Parsing advertisements: MAZDA 6 50.9% (470/923)
# -----Parsing advertisements: MAZDA 6 52.0% (480/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034054411-1b2f/
# -----Parsing advertisements: MAZDA 6 53.1% (490/923)
# -----Parsing advertisements: MAZDA 6 54.2% (500/923)
# -----Parsing advertisements: MAZDA 6 55.3% (510/923)
# -----Parsing advertisements: MAZDA 6 56.3% (520/923)
# -----Parsing advertisements: MAZDA 6 57.4% (530/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1032028929-083e72/
# -----Parsing advertisements: MAZDA 6 58.5% (540/923)
# -----Parsing advertisements: MAZDA 6 59.6% (550/923)
# -----Parsing advertisements: MAZDA 6 60.7% (560/923)
# -----Parsing advertisements: MAZDA 6 61.8% (570/923)
# -----Parsing advertisements: MAZDA 6 62.8% (580/923)
# -----Parsing advertisements: MAZDA 6 63.9% (590/923)
# -----Parsing advertisements: MAZDA 6 65.0% (600/923)
# -----Parsing advertisements: MAZDA 6 66.1% (610/923)
# -----Parsing advertisements: MAZDA 6 67.2% (620/923)
# -----Parsing advertisements: MAZDA 6 68.3% (630/923)
# -----Parsing advertisements: MAZDA 6 69.3% (640/923)
# -----Parsing advertisements: MAZDA 6 70.4% (650/923)
# -----Parsing advertisements: MAZDA 6 71.5% (660/923)
# -----Parsing advertisements: MAZDA 6 72.6% (670/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034054409-dfdd/
# Error with advertisement: https://auto.ru/cars/used/sale/1034080237-5a9e/
# -----Parsing advertisements: MAZDA 6 73.7% (680/923)
# -----Parsing advertisements: MAZDA 6 74.8% (690/923)
# -----Parsing advertisements: MAZDA 6 75.8% (700/923)
# -----Parsing advertisements: MAZDA 6 76.9% (710/923)
# -----Parsing advertisements: MAZDA 6 78.0% (720/923)
# -----Parsing advertisements: MAZDA 6 79.1% (730/923)
# -----Parsing advertisements: MAZDA 6 80.2% (740/923)
# -----Parsing advertisements: MAZDA 6 81.3% (750/923)
# -----Parsing advertisements: MAZDA 6 82.3% (760/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033054247-eead7/
# Error with advertisement: https://auto.ru/cars/used/sale/1032961303-57f0cf/
# -----Parsing advertisements: MAZDA 6 83.4% (770/923)
# -----Parsing advertisements: MAZDA 6 84.5% (780/923)
# -----Parsing advertisements: MAZDA 6 85.6% (790/923)
# -----Parsing advertisements: MAZDA 6 86.7% (800/923)
# -----Parsing advertisements: MAZDA 6 87.8% (810/923)
# -----Parsing advertisements: MAZDA 6 88.8% (820/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1031543417-c110e/
# -----Parsing advertisements: MAZDA 6 89.9% (830/923)
# -----Parsing advertisements: MAZDA 6 91.0% (840/923)
# -----Parsing advertisements: MAZDA 6 92.1% (850/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033692905-4146/
# -----Parsing advertisements: MAZDA 6 93.2% (860/923)
# -----Parsing advertisements: MAZDA 6 94.3% (870/923)
# -----Parsing advertisements: MAZDA 6 95.3% (880/923)
# -----Parsing advertisements: MAZDA 6 96.4% (890/923)
# -----Parsing advertisements: MAZDA 6 97.5% (900/923)
# -----Parsing advertisements: MAZDA 6 98.6% (910/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034058609-82b1/
# -----Parsing advertisements: MAZDA 6 99.7% (920/923)
# ---Parsing advertisements End: MAZDA 6
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/mazda_6_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:17:11.811463
# Total number of advertisements parsed: 907
# Average parsing time per advertisement: 0:00:01.086322
# ===
# ===
# Parsing advertisements pages: Start BMW 5ER
# --Parsing advertising pages  1.9% (1/52)
# --Parsing advertising pages  3.8% (2/52)
# --Parsing advertising pages  5.8% (3/52)
# --Parsing advertising pages  7.7% (4/52)
# --Parsing advertising pages  9.6% (5/52)
# --Parsing advertising pages  11.5% (6/52)
# --Parsing advertising pages  13.5% (7/52)
# --Parsing advertising pages  15.4% (8/52)
# --Parsing advertising pages  17.3% (9/52)
# --Parsing advertising pages  19.2% (10/52)
# --Parsing advertising pages  21.2% (11/52)
# --Parsing advertising pages  23.1% (12/52)
# --Parsing advertising pages  25.0% (13/52)
# --Parsing advertising pages  26.9% (14/52)
# --Parsing advertising pages  28.8% (15/52)
# --Parsing advertising pages  30.8% (16/52)
# --Parsing advertising pages  32.7% (17/52)
# --Parsing advertising pages  34.6% (18/52)
# --Parsing advertising pages  36.5% (19/52)
# --Parsing advertising pages  38.5% (20/52)
# --Parsing advertising pages  40.4% (21/52)
# --Parsing advertising pages  42.3% (22/52)
# --Parsing advertising pages  44.2% (23/52)
# --Parsing advertising pages  46.2% (24/52)
# --Parsing advertising pages  48.1% (25/52)
# --Parsing advertising pages  50.0% (26/52)
# --Parsing advertising pages  51.9% (27/52)
# --Parsing advertising pages  53.8% (28/52)
# --Parsing advertising pages  55.8% (29/52)
# --Parsing advertising pages  57.7% (30/52)
# --Parsing advertising pages  59.6% (31/52)
# --Parsing advertising pages  61.5% (32/52)
# --Parsing advertising pages  63.5% (33/52)
# --Parsing advertising pages  65.4% (34/52)
# --Parsing advertising pages  67.3% (35/52)
# --Parsing advertising pages  69.2% (36/52)
# --Parsing advertising pages  71.2% (37/52)
# --Parsing advertising pages  73.1% (38/52)
# --Parsing advertising pages  75.0% (39/52)
# --Parsing advertising pages  76.9% (40/52)
# --Parsing advertising pages  78.8% (41/52)
# --Parsing advertising pages  80.8% (42/52)
# --Parsing advertising pages  82.7% (43/52)
# --Parsing advertising pages  84.6% (44/52)
# --Parsing advertising pages  86.5% (45/52)
# --Parsing advertising pages  88.5% (46/52)
# --Parsing advertising pages  90.4% (47/52)
# --Parsing advertising pages  92.3% (48/52)
# --Parsing advertising pages  94.2% (49/52)
# --Parsing advertising pages  98.1% (51/52)
# --Parsing advertising pages  100.0% (52/52)
# Parsing advertisements pages: End BMW 5ER
# ---Parsing advertisements Start: BMW 5ER
# -----Parsing advertisements: BMW 5ER 1.1% (10/922)
# -----Parsing advertisements: BMW 5ER 2.2% (20/922)
# -----Parsing advertisements: BMW 5ER 3.3% (30/922)
# -----Parsing advertisements: BMW 5ER 4.3% (40/922)
# -----Parsing advertisements: BMW 5ER 5.4% (50/922)
# -----Parsing advertisements: BMW 5ER 6.5% (60/922)
# -----Parsing advertisements: BMW 5ER 7.6% (70/922)
# -----Parsing advertisements: BMW 5ER 8.7% (80/922)
# -----Parsing advertisements: BMW 5ER 9.8% (90/922)
# -----Parsing advertisements: BMW 5ER 10.8% (100/922)
# -----Parsing advertisements: BMW 5ER 11.9% (110/922)
# -----Parsing advertisements: BMW 5ER 13.0% (120/922)
# -----Parsing advertisements: BMW 5ER 14.1% (130/922)
# -----Parsing advertisements: BMW 5ER 15.2% (140/922)
# -----Parsing advertisements: BMW 5ER 16.3% (150/922)
# -----Parsing advertisements: BMW 5ER 17.4% (160/922)
# -----Parsing advertisements: BMW 5ER 18.4% (170/922)
# -----Parsing advertisements: BMW 5ER 19.5% (180/922)
# -----Parsing advertisements: BMW 5ER 20.6% (190/922)
# -----Parsing advertisements: BMW 5ER 21.7% (200/922)
# -----Parsing advertisements: BMW 5ER 22.8% (210/922)
# -----Parsing advertisements: BMW 5ER 23.9% (220/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1033695821-8f359/
# -----Parsing advertisements: BMW 5ER 24.9% (230/922)
# -----Parsing advertisements: BMW 5ER 26.0% (240/922)
# -----Parsing advertisements: BMW 5ER 27.1% (250/922)
# -----Parsing advertisements: BMW 5ER 28.2% (260/922)
# -----Parsing advertisements: BMW 5ER 29.3% (270/922)
# -----Parsing advertisements: BMW 5ER 30.4% (280/922)
# -----Parsing advertisements: BMW 5ER 31.5% (290/922)
# -----Parsing advertisements: BMW 5ER 32.5% (300/922)
# -----Parsing advertisements: BMW 5ER 33.6% (310/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1034045573-1123/
# -----Parsing advertisements: BMW 5ER 34.7% (320/922)
# -----Parsing advertisements: BMW 5ER 35.8% (330/922)
# -----Parsing advertisements: BMW 5ER 36.9% (340/922)
# -----Parsing advertisements: BMW 5ER 38.0% (350/922)
# -----Parsing advertisements: BMW 5ER 39.0% (360/922)
# -----Parsing advertisements: BMW 5ER 40.1% (370/922)
# -----Parsing advertisements: BMW 5ER 41.2% (380/922)
# -----Parsing advertisements: BMW 5ER 42.3% (390/922)
# -----Parsing advertisements: BMW 5ER 43.4% (400/922)
# -----Parsing advertisements: BMW 5ER 44.5% (410/922)
# -----Parsing advertisements: BMW 5ER 45.6% (420/922)
# -----Parsing advertisements: BMW 5ER 46.6% (430/922)
# -----Parsing advertisements: BMW 5ER 47.7% (440/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1033983079-7205/
# -----Parsing advertisements: BMW 5ER 48.8% (450/922)
# -----Parsing advertisements: BMW 5ER 49.9% (460/922)
# -----Parsing advertisements: BMW 5ER 51.0% (470/922)
# -----Parsing advertisements: BMW 5ER 52.1% (480/922)
# -----Parsing advertisements: BMW 5ER 53.1% (490/922)
# -----Parsing advertisements: BMW 5ER 54.2% (500/922)
# -----Parsing advertisements: BMW 5ER 55.3% (510/922)
# -----Parsing advertisements: BMW 5ER 56.4% (520/922)
# -----Parsing advertisements: BMW 5ER 57.5% (530/922)
# -----Parsing advertisements: BMW 5ER 58.6% (540/922)
# -----Parsing advertisements: BMW 5ER 59.7% (550/922)
# -----Parsing advertisements: BMW 5ER 60.7% (560/922)
# -----Parsing advertisements: BMW 5ER 61.8% (570/922)
# -----Parsing advertisements: BMW 5ER 62.9% (580/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1034991967-164fa/
# -----Parsing advertisements: BMW 5ER 64.0% (590/922)
# -----Parsing advertisements: BMW 5ER 65.1% (600/922)
# -----Parsing advertisements: BMW 5ER 66.2% (610/922)
# -----Parsing advertisements: BMW 5ER 67.2% (620/922)
# -----Parsing advertisements: BMW 5ER 68.3% (630/922)
# -----Parsing advertisements: BMW 5ER 69.4% (640/922)
# -----Parsing advertisements: BMW 5ER 70.5% (650/922)
# -----Parsing advertisements: BMW 5ER 71.6% (660/922)
# -----Parsing advertisements: BMW 5ER 72.7% (670/922)
# -----Parsing advertisements: BMW 5ER 73.8% (680/922)
# -----Parsing advertisements: BMW 5ER 74.8% (690/922)
# -----Parsing advertisements: BMW 5ER 75.9% (700/922)
# -----Parsing advertisements: BMW 5ER 77.0% (710/922)
# -----Parsing advertisements: BMW 5ER 78.1% (720/922)
# -----Parsing advertisements: BMW 5ER 79.2% (730/922)
# -----Parsing advertisements: BMW 5ER 80.3% (740/922)
# -----Parsing advertisements: BMW 5ER 81.3% (750/922)
# -----Parsing advertisements: BMW 5ER 82.4% (760/922)
# -----Parsing advertisements: BMW 5ER 83.5% (770/922)
# -----Parsing advertisements: BMW 5ER 84.6% (780/922)
# -----Parsing advertisements: BMW 5ER 85.7% (790/922)
# -----Parsing advertisements: BMW 5ER 86.8% (800/922)
# -----Parsing advertisements: BMW 5ER 87.9% (810/922)
# -----Parsing advertisements: BMW 5ER 88.9% (820/922)
# -----Parsing advertisements: BMW 5ER 90.0% (830/922)
# -----Parsing advertisements: BMW 5ER 91.1% (840/922)
# -----Parsing advertisements: BMW 5ER 92.2% (850/922)
# -----Parsing advertisements: BMW 5ER 93.3% (860/922)
# -----Parsing advertisements: BMW 5ER 94.4% (870/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1034088974-b983/
# -----Parsing advertisements: BMW 5ER 95.4% (880/922)
# -----Parsing advertisements: BMW 5ER 96.5% (890/922)
# -----Parsing advertisements: BMW 5ER 97.6% (900/922)
# Error with advertisement: https://auto.ru/cars/used/sale/1034001801-42bc/
# -----Parsing advertisements: BMW 5ER 98.7% (910/922)
# -----Parsing advertisements: BMW 5ER 99.8% (920/922)
# ---Parsing advertisements End: BMW 5ER
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/bmw_5er_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:17:48.092642
# Total number of advertisements parsed: 916
# Average parsing time per advertisement: 0:00:01.066101
# ===
# ===
# Parsing advertisements pages: Start AUDI A6
# --Parsing advertising pages  2.8% (1/36)
# --Parsing advertising pages  5.6% (2/36)
# --Parsing advertising pages  8.3% (3/36)
# --Parsing advertising pages  11.1% (4/36)
# --Parsing advertising pages  13.9% (5/36)
# --Parsing advertising pages  16.7% (6/36)
# --Parsing advertising pages  19.4% (7/36)
# --Parsing advertising pages  22.2% (8/36)
# --Parsing advertising pages  25.0% (9/36)
# --Parsing advertising pages  27.8% (10/36)
# --Parsing advertising pages  30.6% (11/36)
# --Parsing advertising pages  33.3% (12/36)
# --Parsing advertising pages  36.1% (13/36)
# --Parsing advertising pages  38.9% (14/36)
# --Parsing advertising pages  41.7% (15/36)
# --Parsing advertising pages  44.4% (16/36)
# --Parsing advertising pages  47.2% (17/36)
# --Parsing advertising pages  50.0% (18/36)
# --Parsing advertising pages  52.8% (19/36)
# --Parsing advertising pages  55.6% (20/36)
# --Parsing advertising pages  58.3% (21/36)
# --Parsing advertising pages  61.1% (22/36)
# --Parsing advertising pages  63.9% (23/36)
# --Parsing advertising pages  66.7% (24/36)
# --Parsing advertising pages  69.4% (25/36)
# --Parsing advertising pages  72.2% (26/36)
# --Parsing advertising pages  75.0% (27/36)
# --Parsing advertising pages  77.8% (28/36)
# --Parsing advertising pages  80.6% (29/36)
# --Parsing advertising pages  83.3% (30/36)
# --Parsing advertising pages  86.1% (31/36)
# --Parsing advertising pages  88.9% (32/36)
# --Parsing advertising pages  91.7% (33/36)
# --Parsing advertising pages  94.4% (34/36)
# --Parsing advertising pages  97.2% (35/36)
# --Parsing advertising pages  100.0% (36/36)
# Parsing advertisements pages: End AUDI A6
# ---Parsing advertisements Start: AUDI A6
# -----Parsing advertisements: AUDI A6 1.1% (10/923)
# -----Parsing advertisements: AUDI A6 2.2% (20/923)
# -----Parsing advertisements: AUDI A6 3.3% (30/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034074805-d44910/
# -----Parsing advertisements: AUDI A6 4.3% (40/923)
# -----Parsing advertisements: AUDI A6 5.4% (50/923)
# -----Parsing advertisements: AUDI A6 6.5% (60/923)
# -----Parsing advertisements: AUDI A6 7.6% (70/923)
# -----Parsing advertisements: AUDI A6 8.7% (80/923)
# -----Parsing advertisements: AUDI A6 9.8% (90/923)
# -----Parsing advertisements: AUDI A6 10.8% (100/923)
# -----Parsing advertisements: AUDI A6 11.9% (110/923)
# -----Parsing advertisements: AUDI A6 13.0% (120/923)
# -----Parsing advertisements: AUDI A6 14.1% (130/923)
# -----Parsing advertisements: AUDI A6 15.2% (140/923)
# -----Parsing advertisements: AUDI A6 16.3% (150/923)
# -----Parsing advertisements: AUDI A6 17.3% (160/923)
# -----Parsing advertisements: AUDI A6 18.4% (170/923)
# -----Parsing advertisements: AUDI A6 19.5% (180/923)
# -----Parsing advertisements: AUDI A6 20.6% (190/923)
# -----Parsing advertisements: AUDI A6 21.7% (200/923)
# -----Parsing advertisements: AUDI A6 22.8% (210/923)
# -----Parsing advertisements: AUDI A6 23.8% (220/923)
# -----Parsing advertisements: AUDI A6 24.9% (230/923)
# -----Parsing advertisements: AUDI A6 26.0% (240/923)
# -----Parsing advertisements: AUDI A6 27.1% (250/923)
# -----Parsing advertisements: AUDI A6 28.2% (260/923)
# -----Parsing advertisements: AUDI A6 29.3% (270/923)
# -----Parsing advertisements: AUDI A6 30.3% (280/923)
# -----Parsing advertisements: AUDI A6 31.4% (290/923)
# -----Parsing advertisements: AUDI A6 32.5% (300/923)
# -----Parsing advertisements: AUDI A6 33.6% (310/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034015767-beea/
# -----Parsing advertisements: AUDI A6 34.7% (320/923)
# -----Parsing advertisements: AUDI A6 35.8% (330/923)
# -----Parsing advertisements: AUDI A6 36.8% (340/923)
# -----Parsing advertisements: AUDI A6 37.9% (350/923)
# -----Parsing advertisements: AUDI A6 39.0% (360/923)
# -----Parsing advertisements: AUDI A6 40.1% (370/923)
# -----Parsing advertisements: AUDI A6 41.2% (380/923)
# -----Parsing advertisements: AUDI A6 42.3% (390/923)
# -----Parsing advertisements: AUDI A6 43.3% (400/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1032837221-743d3/
# -----Parsing advertisements: AUDI A6 44.4% (410/923)
# -----Parsing advertisements: AUDI A6 45.5% (420/923)
# -----Parsing advertisements: AUDI A6 46.6% (430/923)
# -----Parsing advertisements: AUDI A6 47.7% (440/923)
# -----Parsing advertisements: AUDI A6 48.8% (450/923)
# -----Parsing advertisements: AUDI A6 49.8% (460/923)
# -----Parsing advertisements: AUDI A6 50.9% (470/923)
# -----Parsing advertisements: AUDI A6 52.0% (480/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1033916437-3886/
# -----Parsing advertisements: AUDI A6 53.1% (490/923)
# -----Parsing advertisements: AUDI A6 54.2% (500/923)
# -----Parsing advertisements: AUDI A6 55.3% (510/923)
# -----Parsing advertisements: AUDI A6 56.3% (520/923)
# -----Parsing advertisements: AUDI A6 57.4% (530/923)
# -----Parsing advertisements: AUDI A6 58.5% (540/923)
# -----Parsing advertisements: AUDI A6 59.6% (550/923)
# -----Parsing advertisements: AUDI A6 60.7% (560/923)
# -----Parsing advertisements: AUDI A6 61.8% (570/923)
# -----Parsing advertisements: AUDI A6 62.8% (580/923)
# -----Parsing advertisements: AUDI A6 63.9% (590/923)
# -----Parsing advertisements: AUDI A6 65.0% (600/923)
# -----Parsing advertisements: AUDI A6 66.1% (610/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034592307-d98918/
# -----Parsing advertisements: AUDI A6 67.2% (620/923)
# -----Parsing advertisements: AUDI A6 68.3% (630/923)
# -----Parsing advertisements: AUDI A6 69.3% (640/923)
# -----Parsing advertisements: AUDI A6 70.4% (650/923)
# -----Parsing advertisements: AUDI A6 71.5% (660/923)
# -----Parsing advertisements: AUDI A6 72.6% (670/923)
# -----Parsing advertisements: AUDI A6 73.7% (680/923)
# -----Parsing advertisements: AUDI A6 74.8% (690/923)
# -----Parsing advertisements: AUDI A6 75.8% (700/923)
# -----Parsing advertisements: AUDI A6 76.9% (710/923)
# -----Parsing advertisements: AUDI A6 78.0% (720/923)
# -----Parsing advertisements: AUDI A6 79.1% (730/923)
# -----Parsing advertisements: AUDI A6 80.2% (740/923)
# -----Parsing advertisements: AUDI A6 81.3% (750/923)
# -----Parsing advertisements: AUDI A6 82.3% (760/923)
# Error with advertisement: https://auto.ru/cars/used/sale/1034081571-c1ec/
# -----Parsing advertisements: AUDI A6 83.4% (770/923)
# -----Parsing advertisements: AUDI A6 84.5% (780/923)
# -----Parsing advertisements: AUDI A6 85.6% (790/923)
# -----Parsing advertisements: AUDI A6 86.7% (800/923)
# -----Parsing advertisements: AUDI A6 87.8% (810/923)
# -----Parsing advertisements: AUDI A6 88.8% (820/923)
# -----Parsing advertisements: AUDI A6 89.9% (830/923)
# -----Parsing advertisements: AUDI A6 91.0% (840/923)
# -----Parsing advertisements: AUDI A6 92.1% (850/923)
# -----Parsing advertisements: AUDI A6 93.2% (860/923)
# -----Parsing advertisements: AUDI A6 94.3% (870/923)
# -----Parsing advertisements: AUDI A6 95.3% (880/923)
# -----Parsing advertisements: AUDI A6 96.4% (890/923)
# -----Parsing advertisements: AUDI A6 97.5% (900/923)
# -----Parsing advertisements: AUDI A6 98.6% (910/923)
# -----Parsing advertisements: AUDI A6 99.7% (920/923)
# ---Parsing advertisements End: AUDI A6
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/audi_a6_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:17:02.429175
# Total number of advertisements parsed: 917
# Average parsing time per advertisement: 0:00:01.049031
# ===
# ===
# Parsing advertisements pages: Start FORD MONDEO
# --Parsing advertising pages  3.1% (1/32)
# --Parsing advertising pages  6.2% (2/32)
# --Parsing advertising pages  9.4% (3/32)
# --Parsing advertising pages  12.5% (4/32)
# --Parsing advertising pages  15.6% (5/32)
# --Parsing advertising pages  18.8% (6/32)
# --Parsing advertising pages  21.9% (7/32)
# --Parsing advertising pages  25.0% (8/32)
# --Parsing advertising pages  28.1% (9/32)
# --Parsing advertising pages  31.2% (10/32)
# --Parsing advertising pages  34.4% (11/32)
# --Parsing advertising pages  37.5% (12/32)
# --Parsing advertising pages  40.6% (13/32)
# --Parsing advertising pages  43.8% (14/32)
# --Parsing advertising pages  46.9% (15/32)
# --Parsing advertising pages  50.0% (16/32)
# --Parsing advertising pages  53.1% (17/32)
# --Parsing advertising pages  56.2% (18/32)
# --Parsing advertising pages  59.4% (19/32)
# --Parsing advertising pages  62.5% (20/32)
# --Parsing advertising pages  65.6% (21/32)
# --Parsing advertising pages  68.8% (22/32)
# --Parsing advertising pages  71.9% (23/32)
# --Parsing advertising pages  75.0% (24/32)
# --Parsing advertising pages  78.1% (25/32)
# --Parsing advertising pages  81.2% (26/32)
# --Parsing advertising pages  84.4% (27/32)
# --Parsing advertising pages  87.5% (28/32)
# --Parsing advertising pages  90.6% (29/32)
# --Parsing advertising pages  93.8% (30/32)
# --Parsing advertising pages  96.9% (31/32)
# --Parsing advertising pages  100.0% (32/32)
# Parsing advertisements pages: End FORD MONDEO
# ---Parsing advertisements Start: FORD MONDEO
# -----Parsing advertisements: FORD MONDEO 1.1% (10/913)
# -----Parsing advertisements: FORD MONDEO 2.2% (20/913)
# -----Parsing advertisements: FORD MONDEO 3.3% (30/913)
# -----Parsing advertisements: FORD MONDEO 4.4% (40/913)
# -----Parsing advertisements: FORD MONDEO 5.5% (50/913)
# -----Parsing advertisements: FORD MONDEO 6.6% (60/913)
# -----Parsing advertisements: FORD MONDEO 7.7% (70/913)
# -----Parsing advertisements: FORD MONDEO 8.8% (80/913)
# -----Parsing advertisements: FORD MONDEO 9.9% (90/913)
# -----Parsing advertisements: FORD MONDEO 11.0% (100/913)
# -----Parsing advertisements: FORD MONDEO 12.0% (110/913)
# -----Parsing advertisements: FORD MONDEO 13.1% (120/913)
# -----Parsing advertisements: FORD MONDEO 14.2% (130/913)
# -----Parsing advertisements: FORD MONDEO 15.3% (140/913)
# -----Parsing advertisements: FORD MONDEO 16.4% (150/913)
# -----Parsing advertisements: FORD MONDEO 17.5% (160/913)
# -----Parsing advertisements: FORD MONDEO 18.6% (170/913)
# -----Parsing advertisements: FORD MONDEO 19.7% (180/913)
# -----Parsing advertisements: FORD MONDEO 20.8% (190/913)
# -----Parsing advertisements: FORD MONDEO 21.9% (200/913)
# -----Parsing advertisements: FORD MONDEO 23.0% (210/913)
# -----Parsing advertisements: FORD MONDEO 24.1% (220/913)
# -----Parsing advertisements: FORD MONDEO 25.2% (230/913)
# -----Parsing advertisements: FORD MONDEO 26.3% (240/913)
# -----Parsing advertisements: FORD MONDEO 27.4% (250/913)
# Error with advertisement: https://auto.ru/cars/used/sale/1034054365-d7e3d0/
# -----Parsing advertisements: FORD MONDEO 28.5% (260/913)
# -----Parsing advertisements: FORD MONDEO 29.6% (270/913)
# -----Parsing advertisements: FORD MONDEO 30.7% (280/913)
# -----Parsing advertisements: FORD MONDEO 31.8% (290/913)
# -----Parsing advertisements: FORD MONDEO 32.9% (300/913)
# -----Parsing advertisements: FORD MONDEO 34.0% (310/913)
# -----Parsing advertisements: FORD MONDEO 35.0% (320/913)
# -----Parsing advertisements: FORD MONDEO 36.1% (330/913)
# -----Parsing advertisements: FORD MONDEO 37.2% (340/913)
# -----Parsing advertisements: FORD MONDEO 38.3% (350/913)
# -----Parsing advertisements: FORD MONDEO 39.4% (360/913)
# -----Parsing advertisements: FORD MONDEO 40.5% (370/913)
# -----Parsing advertisements: FORD MONDEO 41.6% (380/913)
# -----Parsing advertisements: FORD MONDEO 42.7% (390/913)
# -----Parsing advertisements: FORD MONDEO 43.8% (400/913)
# -----Parsing advertisements: FORD MONDEO 44.9% (410/913)
# -----Parsing advertisements: FORD MONDEO 46.0% (420/913)
# -----Parsing advertisements: FORD MONDEO 47.1% (430/913)
# -----Parsing advertisements: FORD MONDEO 48.2% (440/913)
# -----Parsing advertisements: FORD MONDEO 49.3% (450/913)
# -----Parsing advertisements: FORD MONDEO 50.4% (460/913)
# ...
# -----Parsing advertisements: FORD MONDEO 65.7% (600/913)
# -----Parsing advertisements: FORD MONDEO 66.8% (610/913)
# -----Parsing advertisements: FORD MONDEO 67.9% (620/913)
# -----Parsing advertisements: FORD MONDEO 69.0% (630/913)
# -----Parsing advertisements: FORD MONDEO 70.1% (640/913)
# -----Parsing advertisements: FORD MONDEO 71.2% (650/913)
# -----Parsing advertisements: FORD MONDEO 72.3% (660/913)
# -----Parsing advertisements: FORD MONDEO 73.4% (670/913)
# -----Parsing advertisements: FORD MONDEO 74.5% (680/913)
# -----Parsing advertisements: FORD MONDEO 75.6% (690/913)
# -----Parsing advertisements: FORD MONDEO 76.7% (700/913)
# -----Parsing advertisements: FORD MONDEO 77.8% (710/913)
# -----Parsing advertisements: FORD MONDEO 78.9% (720/913)
# -----Parsing advertisements: FORD MONDEO 80.0% (730/913)
# -----Parsing advertisements: FORD MONDEO 81.1% (740/913)
# -----Parsing advertisements: FORD MONDEO 82.1% (750/913)
# -----Parsing advertisements: FORD MONDEO 83.2% (760/913)
# -----Parsing advertisements: FORD MONDEO 84.3% (770/913)
# -----Parsing advertisements: FORD MONDEO 85.4% (780/913)
# -----Parsing advertisements: FORD MONDEO 86.5% (790/913)
# -----Parsing advertisements: FORD MONDEO 87.6% (800/913)
# -----Parsing advertisements: FORD MONDEO 88.7% (810/913)
# -----Parsing advertisements: FORD MONDEO 89.8% (820/913)
# -----Parsing advertisements: FORD MONDEO 90.9% (830/913)
# -----Parsing advertisements: FORD MONDEO 92.0% (840/913)
# -----Parsing advertisements: FORD MONDEO 93.1% (850/913)
# -----Parsing advertisements: FORD MONDEO 94.2% (860/913)
# -----Parsing advertisements: FORD MONDEO 95.3% (870/913)
# -----Parsing advertisements: FORD MONDEO 96.4% (880/913)
# -----Parsing advertisements: FORD MONDEO 97.5% (890/913)
# -----Parsing advertisements: FORD MONDEO 98.6% (900/913)
# -----Parsing advertisements: FORD MONDEO 99.7% (910/913)
# ---Parsing advertisements End: FORD MONDEO
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/ford_mondeo_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:16:10.508448
# Total number of advertisements parsed: 910
# Average parsing time per advertisement: 0:00:01.010025
# ===
# ===
# Parsing advertisements pages: Start INFINITI G35
# --Parsing advertising pages  20.0% (1/5)
# --Parsing advertising pages  40.0% (2/5)
# --Parsing advertising pages  60.0% (3/5)
# --Parsing advertising pages  80.0% (4/5)
# --Parsing advertising pages  100.0% (5/5)
# Parsing advertisements pages: End INFINITI G35
# ---Parsing advertisements Start: INFINITI G35
# -----Parsing advertisements: INFINITI G35 5.7% (10/176)
# -----Parsing advertisements: INFINITI G35 11.4% (20/176)
# -----Parsing advertisements: INFINITI G35 17.0% (30/176)
# -----Parsing advertisements: INFINITI G35 22.7% (40/176)
# -----Parsing advertisements: INFINITI G35 28.4% (50/176)
# -----Parsing advertisements: INFINITI G35 34.1% (60/176)
# -----Parsing advertisements: INFINITI G35 39.8% (70/176)
# -----Parsing advertisements: INFINITI G35 45.5% (80/176)
# -----Parsing advertisements: INFINITI G35 51.1% (90/176)
# -----Parsing advertisements: INFINITI G35 56.8% (100/176)
# -----Parsing advertisements: INFINITI G35 62.5% (110/176)
# -----Parsing advertisements: INFINITI G35 68.2% (120/176)
# -----Parsing advertisements: INFINITI G35 73.9% (130/176)
# -----Parsing advertisements: INFINITI G35 79.5% (140/176)
# -----Parsing advertisements: INFINITI G35 85.2% (150/176)
# -----Parsing advertisements: INFINITI G35 90.9% (160/176)
# -----Parsing advertisements: INFINITI G35 96.6% (170/176)
# ---Parsing advertisements End: INFINITI G35
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/infiniti_g35_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:02:58.157109
# Total number of advertisements parsed: 176
# Average parsing time per advertisement: 0:00:00.965629
# ===
# ===
# Parsing advertisements pages: Start NISSAN TEANA
# --Parsing advertising pages  4.3% (1/23)
# --Parsing advertising pages  8.7% (2/23)
# --Parsing advertising pages  13.0% (3/23)
# --Parsing advertising pages  17.4% (4/23)
# --Parsing advertising pages  21.7% (5/23)
# --Parsing advertising pages  26.1% (6/23)
# --Parsing advertising pages  30.4% (7/23)
# --Parsing advertising pages  34.8% (8/23)
# --Parsing advertising pages  39.1% (9/23)
# --Parsing advertising pages  43.5% (10/23)
# --Parsing advertising pages  47.8% (11/23)
# --Parsing advertising pages  52.2% (12/23)
# --Parsing advertising pages  56.5% (13/23)
# --Parsing advertising pages  60.9% (14/23)
# --Parsing advertising pages  65.2% (15/23)
# --Parsing advertising pages  69.6% (16/23)
# --Parsing advertising pages  73.9% (17/23)
# --Parsing advertising pages  78.3% (18/23)
# --Parsing advertising pages  82.6% (19/23)
# --Parsing advertising pages  87.0% (20/23)
# --Parsing advertising pages  91.3% (21/23)
# --Parsing advertising pages  95.7% (22/23)
# --Parsing advertising pages  100.0% (23/23)
# Parsing advertisements pages: End NISSAN TEANA
# ---Parsing advertisements Start: NISSAN TEANA
# -----Parsing advertisements: NISSAN TEANA 1.2% (10/839)
# -----Parsing advertisements: NISSAN TEANA 2.4% (20/839)
# -----Parsing advertisements: NISSAN TEANA 3.6% (30/839)
# -----Parsing advertisements: NISSAN TEANA 4.8% (40/839)
# -----Parsing advertisements: NISSAN TEANA 6.0% (50/839)
# -----Parsing advertisements: NISSAN TEANA 7.2% (60/839)
# -----Parsing advertisements: NISSAN TEANA 8.3% (70/839)
# -----Parsing advertisements: NISSAN TEANA 9.5% (80/839)
# -----Parsing advertisements: NISSAN TEANA 10.7% (90/839)
# -----Parsing advertisements: NISSAN TEANA 11.9% (100/839)
# Error with advertisement: https://auto.ru/cars/used/sale/1034012083-2b9c4f/
# -----Parsing advertisements: NISSAN TEANA 13.1% (110/839)
# -----Parsing advertisements: NISSAN TEANA 14.3% (120/839)
# -----Parsing advertisements: NISSAN TEANA 15.5% (130/839)
# -----Parsing advertisements: NISSAN TEANA 16.7% (140/839)
# -----Parsing advertisements: NISSAN TEANA 17.9% (150/839)
# -----Parsing advertisements: NISSAN TEANA 19.1% (160/839)
# -----Parsing advertisements: NISSAN TEANA 20.3% (170/839)
# Error with advertisement: https://auto.ru/cars/used/sale/1034073043-017f/
# -----Parsing advertisements: NISSAN TEANA 21.5% (180/839)
# -----Parsing advertisements: NISSAN TEANA 22.6% (190/839)
# -----Parsing advertisements: NISSAN TEANA 23.8% (200/839)
# -----Parsing advertisements: NISSAN TEANA 25.0% (210/839)
# -----Parsing advertisements: NISSAN TEANA 26.2% (220/839)
# -----Parsing advertisements: NISSAN TEANA 27.4% (230/839)
# -----Parsing advertisements: NISSAN TEANA 28.6% (240/839)
# -----Parsing advertisements: NISSAN TEANA 29.8% (250/839)
# -----Parsing advertisements: NISSAN TEANA 31.0% (260/839)
# -----Parsing advertisements: NISSAN TEANA 32.2% (270/839)
# -----Parsing advertisements: NISSAN TEANA 33.4% (280/839)
# -----Parsing advertisements: NISSAN TEANA 34.6% (290/839)
# -----Parsing advertisements: NISSAN TEANA 35.8% (300/839)
# -----Parsing advertisements: NISSAN TEANA 36.9% (310/839)
# -----Parsing advertisements: NISSAN TEANA 38.1% (320/839)
# -----Parsing advertisements: NISSAN TEANA 39.3% (330/839)
# Error with advertisement: https://auto.ru/cars/used/sale/1023168899-7f36a/
# -----Parsing advertisements: NISSAN TEANA 40.5% (340/839)
# -----Parsing advertisements: NISSAN TEANA 41.7% (350/839)
# -----Parsing advertisements: NISSAN TEANA 42.9% (360/839)
# -----Parsing advertisements: NISSAN TEANA 44.1% (370/839)
# -----Parsing advertisements: NISSAN TEANA 45.3% (380/839)
# -----Parsing advertisements: NISSAN TEANA 46.5% (390/839)
# -----Parsing advertisements: NISSAN TEANA 47.7% (400/839)
# -----Parsing advertisements: NISSAN TEANA 48.9% (410/839)
# -----Parsing advertisements: NISSAN TEANA 50.1% (420/839)
# -----Parsing advertisements: NISSAN TEANA 51.3% (430/839)
# -----Parsing advertisements: NISSAN TEANA 52.4% (440/839)
# -----Parsing advertisements: NISSAN TEANA 53.6% (450/839)
# -----Parsing advertisements: NISSAN TEANA 54.8% (460/839)
# -----Parsing advertisements: NISSAN TEANA 56.0% (470/839)
# -----Parsing advertisements: NISSAN TEANA 57.2% (480/839)
# -----Parsing advertisements: NISSAN TEANA 58.4% (490/839)
# -----Parsing advertisements: NISSAN TEANA 59.6% (500/839)
# -----Parsing advertisements: NISSAN TEANA 60.8% (510/839)
# -----Parsing advertisements: NISSAN TEANA 62.0% (520/839)
# Error with advertisement: https://auto.ru/cars/used/sale/1034054451-105213/
# -----Parsing advertisements: NISSAN TEANA 63.2% (530/839)
# -----Parsing advertisements: NISSAN TEANA 64.4% (540/839)
# -----Parsing advertisements: NISSAN TEANA 65.6% (550/839)
# -----Parsing advertisements: NISSAN TEANA 66.7% (560/839)
# -----Parsing advertisements: NISSAN TEANA 67.9% (570/839)
# -----Parsing advertisements: NISSAN TEANA 69.1% (580/839)
# -----Parsing advertisements: NISSAN TEANA 70.3% (590/839)
# -----Parsing advertisements: NISSAN TEANA 71.5% (600/839)
# -----Parsing advertisements: NISSAN TEANA 72.7% (610/839)
# -----Parsing advertisements: NISSAN TEANA 73.9% (620/839)
# -----Parsing advertisements: NISSAN TEANA 75.1% (630/839)
# -----Parsing advertisements: NISSAN TEANA 76.3% (640/839)
# -----Parsing advertisements: NISSAN TEANA 77.5% (650/839)
# Error with advertisement: https://auto.ru/cars/used/sale/1015480697-2d7a3/
# -----Parsing advertisements: NISSAN TEANA 78.7% (660/839)
# -----Parsing advertisements: NISSAN TEANA 79.9% (670/839)
# -----Parsing advertisements: NISSAN TEANA 81.0% (680/839)
# -----Parsing advertisements: NISSAN TEANA 82.2% (690/839)
# -----Parsing advertisements: NISSAN TEANA 83.4% (700/839)
# -----Parsing advertisements: NISSAN TEANA 84.6% (710/839)
# -----Parsing advertisements: NISSAN TEANA 85.8% (720/839)
# -----Parsing advertisements: NISSAN TEANA 87.0% (730/839)
# -----Parsing advertisements: NISSAN TEANA 88.2% (740/839)
# -----Parsing advertisements: NISSAN TEANA 89.4% (750/839)
# -----Parsing advertisements: NISSAN TEANA 90.6% (760/839)
# -----Parsing advertisements: NISSAN TEANA 91.8% (770/839)
# -----Parsing advertisements: NISSAN TEANA 93.0% (780/839)
# -----Parsing advertisements: NISSAN TEANA 94.2% (790/839)
# -----Parsing advertisements: NISSAN TEANA 95.4% (800/839)
# -----Parsing advertisements: NISSAN TEANA 96.5% (810/839)
# -----Parsing advertisements: NISSAN TEANA 97.7% (820/839)
# -----Parsing advertisements: NISSAN TEANA 98.9% (830/839)
# ---Parsing advertisements End: NISSAN TEANA
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/nissan_teana_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:14:18.394196
# Total number of advertisements parsed: 834
# Average parsing time per advertisement: 0:00:00.984873
# ===
# ===
# Parsing advertisements pages: Start OPEL INSIGNIA
# --Parsing advertising pages  12.5% (1/8)
# --Parsing advertising pages  25.0% (2/8)
# --Parsing advertising pages  37.5% (3/8)
# --Parsing advertising pages  50.0% (4/8)
# --Parsing advertising pages  62.5% (5/8)
# --Parsing advertising pages  75.0% (6/8)
# --Parsing advertising pages  87.5% (7/8)
# --Parsing advertising pages  100.0% (8/8)
# Parsing advertisements pages: End OPEL INSIGNIA
# ---Parsing advertisements Start: OPEL INSIGNIA
# -----Parsing advertisements: OPEL INSIGNIA 3.8% (10/261)
# -----Parsing advertisements: OPEL INSIGNIA 7.7% (20/261)
# -----Parsing advertisements: OPEL INSIGNIA 11.5% (30/261)
# -----Parsing advertisements: OPEL INSIGNIA 15.3% (40/261)
# -----Parsing advertisements: OPEL INSIGNIA 19.2% (50/261)
# -----Parsing advertisements: OPEL INSIGNIA 23.0% (60/261)
# -----Parsing advertisements: OPEL INSIGNIA 26.8% (70/261)
# -----Parsing advertisements: OPEL INSIGNIA 30.7% (80/261)
# -----Parsing advertisements: OPEL INSIGNIA 34.5% (90/261)
# -----Parsing advertisements: OPEL INSIGNIA 38.3% (100/261)
# -----Parsing advertisements: OPEL INSIGNIA 42.1% (110/261)
# -----Parsing advertisements: OPEL INSIGNIA 46.0% (120/261)
# -----Parsing advertisements: OPEL INSIGNIA 49.8% (130/261)
# -----Parsing advertisements: OPEL INSIGNIA 53.6% (140/261)
# -----Parsing advertisements: OPEL INSIGNIA 57.5% (150/261)
# -----Parsing advertisements: OPEL INSIGNIA 61.3% (160/261)
# -----Parsing advertisements: OPEL INSIGNIA 65.1% (170/261)
# -----Parsing advertisements: OPEL INSIGNIA 69.0% (180/261)
# -----Parsing advertisements: OPEL INSIGNIA 72.8% (190/261)
# -----Parsing advertisements: OPEL INSIGNIA 76.6% (200/261)
# -----Parsing advertisements: OPEL INSIGNIA 80.5% (210/261)
# -----Parsing advertisements: OPEL INSIGNIA 84.3% (220/261)
# -----Parsing advertisements: OPEL INSIGNIA 88.1% (230/261)
# -----Parsing advertisements: OPEL INSIGNIA 92.0% (240/261)
# -----Parsing advertisements: OPEL INSIGNIA 95.8% (250/261)
# -----Parsing advertisements: OPEL INSIGNIA 99.6% (260/261)
# ---Parsing advertisements End: OPEL INSIGNIA
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/opel_insignia_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:04:16.701489
# Total number of advertisements parsed: 261
# Average parsing time per advertisement: 0:00:00.935806
# ===
# ===
# Parsing advertisements pages: Start VOLVO S60
# --Parsing advertising pages  8.3% (1/12)
# --Parsing advertising pages  16.7% (2/12)
# --Parsing advertising pages  25.0% (3/12)
# --Parsing advertising pages  33.3% (4/12)
# --Parsing advertising pages  41.7% (5/12)
# --Parsing advertising pages  50.0% (6/12)
# --Parsing advertising pages  58.3% (7/12)
# --Parsing advertising pages  66.7% (8/12)
# --Parsing advertising pages  75.0% (9/12)
# --Parsing advertising pages  83.3% (10/12)
# --Parsing advertising pages  91.7% (11/12)
# --Parsing advertising pages  100.0% (12/12)
# Parsing advertisements pages: End VOLVO S60
# ---Parsing advertisements Start: VOLVO S60
# -----Parsing advertisements: VOLVO S60 2.4% (10/409)
# -----Parsing advertisements: VOLVO S60 4.9% (20/409)
# -----Parsing advertisements: VOLVO S60 7.3% (30/409)
# -----Parsing advertisements: VOLVO S60 9.8% (40/409)
# -----Parsing advertisements: VOLVO S60 12.2% (50/409)
# -----Parsing advertisements: VOLVO S60 14.7% (60/409)
# -----Parsing advertisements: VOLVO S60 17.1% (70/409)
# -----Parsing advertisements: VOLVO S60 19.6% (80/409)
# -----Parsing advertisements: VOLVO S60 22.0% (90/409)
# Error with advertisement: https://auto.ru/cars/used/sale/1024847277-c928/
# -----Parsing advertisements: VOLVO S60 24.4% (100/409)
# -----Parsing advertisements: VOLVO S60 26.9% (110/409)
# -----Parsing advertisements: VOLVO S60 29.3% (120/409)
# -----Parsing advertisements: VOLVO S60 31.8% (130/409)
# -----Parsing advertisements: VOLVO S60 34.2% (140/409)
# -----Parsing advertisements: VOLVO S60 36.7% (150/409)
# Error with advertisement: https://auto.ru/cars/used/sale/1034962051-b4d9e/
# -----Parsing advertisements: VOLVO S60 39.1% (160/409)
# -----Parsing advertisements: VOLVO S60 41.6% (170/409)
# -----Parsing advertisements: VOLVO S60 44.0% (180/409)
# -----Parsing advertisements: VOLVO S60 46.5% (190/409)
# -----Parsing advertisements: VOLVO S60 48.9% (200/409)
# -----Parsing advertisements: VOLVO S60 51.3% (210/409)
# -----Parsing advertisements: VOLVO S60 53.8% (220/409)
# -----Parsing advertisements: VOLVO S60 56.2% (230/409)
# -----Parsing advertisements: VOLVO S60 58.7% (240/409)
# -----Parsing advertisements: VOLVO S60 61.1% (250/409)
# -----Parsing advertisements: VOLVO S60 63.6% (260/409)
# -----Parsing advertisements: VOLVO S60 66.0% (270/409)
# -----Parsing advertisements: VOLVO S60 68.5% (280/409)
# -----Parsing advertisements: VOLVO S60 70.9% (290/409)
# -----Parsing advertisements: VOLVO S60 73.3% (300/409)
# -----Parsing advertisements: VOLVO S60 75.8% (310/409)
# -----Parsing advertisements: VOLVO S60 78.2% (320/409)
# -----Parsing advertisements: VOLVO S60 80.7% (330/409)
# -----Parsing advertisements: VOLVO S60 83.1% (340/409)
# -----Parsing advertisements: VOLVO S60 85.6% (350/409)
# -----Parsing advertisements: VOLVO S60 88.0% (360/409)
# -----Parsing advertisements: VOLVO S60 90.5% (370/409)
# -----Parsing advertisements: VOLVO S60 92.9% (380/409)
# -----Parsing advertisements: VOLVO S60 95.4% (390/409)
# -----Parsing advertisements: VOLVO S60 97.8% (400/409)
# ---Parsing advertisements End: VOLVO S60
# --Saving File to C:/Users/Vasiliy Poteriaev/Google Диск/analytics/auto_ru/data/D_class/volvo_s60_2016_04_13.pickle
# Done
# ===
# ===
# Full parsing time: 0:06:43.266346
# Total number of advertisements parsed: 407
# Average parsing time per advertisement: 0:00:00.945635
# ===
# ===
