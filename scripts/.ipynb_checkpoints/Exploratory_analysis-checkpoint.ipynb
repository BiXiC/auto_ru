# %%
import pandas as  pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pylab as pylab
import numpy as np
import seaborn as sns

# %% [markdown]
# # Exploratory Analysis

# %%
dt_path = 'C:/Users/Vasiliy Poteriaev/Documents/GitHub/processed data/auto_matrix_2016-04-13.pickle'
dt = pd.read_pickle(dt_path)

# %%
dt.head(2)
# Out:
#    Advertising_num_days      CarName          ID  Price_rub        Seller  \
# 0                     4  Audi A6 III  1034927017     869999  other dealer
# 1                     3   Audi A6 II  1035026097     377000   ДЕЛЬТА-АВТО
#
#                      Seller_location  Views  Car_age        Gear_box  \
# 0              Москва, прочие адреса   9540        6  Автоматическая
# 1  Москва, ул. Подвойского, дом 5/19   5454       12    Механическая
#
#   Parsing date  Autocode_checked Owners_N  Last_owner_time_years  \
# 0   2016-04-13                 1        2               1.583333
# 1   2016-04-13                 0        1               1.583333
#
#    Warranty_end  Engine_capacity  Engine_hp Engine_fuel_type        Body_type  \
# 0             0              3.0        290           бензин            Седан
# 1             0              2.5        163           дизель  Универсал 5 дв.
#
#        Swap_type  Original_car_passport Wheel_drive_type  run_km  \
# 0  Не интересует                      1           Полный   99000
# 1  Не интересует                      1         Передний   75422
#
#    Left_steering  is_metallic_color    Color  \
# 0              1                  1   Черный
# 1              1                  0  Красный
#
#    Opt_Обивка салона: комбинированный  Opt_Цвет салона: темный  \
# 0                                   1                        1
# 1                                   0                        1
#
#    Opt_Тонированные стекла  Opt_Ксеноновые фары  Opt_  \
# 0                        1                    1     1
# 1                        1                    0     1
#
#    Opt_Легкосплавные диски: 17"  Opt_Иммобилайзер  Opt_Штатная  \
# 0                             1                 1            1
# 1                             0                 1            1
#
#    Opt_Бортовой компьютер  Opt_Датчик дождя  Opt_Датчик света  \
# 0                       1                 1                 1
# 1                       1                 0                 1
#
#    Opt_Круиз-контроль  Opt_Навигационная система  Opt_Обогрев зеркал  \
# 0                   1                          1                   1
# 1                   1                          0                   1
#
#    Opt_Омыватель фар  Opt_Центральный замок  Opt_Усилитель руля  \
# 0                  1                      1                   1
# 1                  1                      1                   1
#
#    Opt_Подогрев руля  Opt_Обогрев сидений  Opt_Количество мест: 5  \
# 0                  1                    1                       1
# 1                  0                    1                       1
#
#    Opt_Климат: климат-контроль 2-зонный  Opt_Электропривод зеркал  \
# 0                                     1                         1
# 1                                     1                         1
#
#    Opt_Стеклоподъемники: электро все  Opt_Сиденье водителя: электро  \
# 0                                  1                              1
# 1                                  1                              1
#
#    Opt_Сиденье пассажира: электро   Opt_Регулировка руля: электро  \
# 0                                1                              1
# 1                                1                              0
#
#    Opt_Антиблокировочная система (ABS)  Opt_Антипробуксовочная система  \
# 0                                    1                               1
# 1                                    1                               1
#
#    Opt_Система курсовой устойчивости  \
# 0                                  1
# 1                                  1
#
#    Opt_Подушки безопасности: передние и боковые  Opt_Парктроник  Opt_CD  \
# 0                                             1               1       1
# 1                                             1               1       1
#
#    Opt_TV  Opt_Обивка салона: кожа  Opt_Люк на крыше  \
# 0       1                        0                 0
# 1       1                        1                 1
#
#    Opt_Легкосплавные диски: 16"  Opt_Обратная связь  \
# 0                             0                   0
# 1                             1                   1
#
#    Opt_Дистанционный запуск двигателя  \
# 0                                   0
# 1                                   1
#
#    Opt_Регулировка руля: в одной плоскости  Opt_Легкосплавные диски: 18"  \
# 0                                        0                             0
# 1                                        1                             0
#
#    Opt_Сиденье водителя: с памятью положения  \
# 0                                          0
# 1                                          0
#
#    Opt_Регулировка руля: в двух плоскостях  Opt_Цвет салона: светлый  \
# 0                                        0                         0
# 1                                        0                         0
#
#    Opt_Подушки безопасности: водителя и пассажира  \
# 0                                               0
# 1                                               0
#
#    Opt_Легкосплавные диски: 12"  Opt_Климат: климат-контроль 1-зонный  \
# 0                             0                                     0
# 1                             0                                     0
#
#    Opt_Стеклоподъемники: электро передние  Opt_Сиденье водителя: ручная   \
# 0                                       0                              0
# 1                                       0                              0
#
#    Opt_Сиденье пассажира: ручная   Opt_Обивка салона: велюр  Opt_Кассетник  \
# 0                               0                         0              0
# 1                               0                         0              0
#
#    Opt_Климат: климат-контроль 3-зонный  Opt_Стеклоподъемники: ручные  \
# 0                                     0                             0
# 1                                     0                             0
#
#    Opt_Обивка салона: ткань  Opt_Сиденье пассажира: с памятью положения  \
# 0                         0                                           0
# 1                         0                                           0
#
#    Opt_Количество мест: 2  Opt_Легкосплавные диски: 15"  \
# 0                       0                             0
# 1                       0                             0
#
#    Opt_Количество мест: 4  Opt_Легкосплавные диски: 19"  \
# 0                       0                             0
# 1                       0                             0
#
#    Opt_Сиденье пассажира: ручная по высоте  \
# 0                                        0
# 1                                        0
#
#    Opt_Сиденье водителя: ручная по высоте  Opt_Количество мест: 7  \
# 0                                       0                       0
# 1                                       0                       0
#
#    Opt_Климат: кондиционер  Opt_Газобаллонное оборудование  \
# 0                        0                               0
# 1                        0                               0
#
#    Opt_Легкосплавные диски: 20"  Opt_Легкосплавные диски: 14"  \
# 0                             0                             0
# 1                             0                             0
#
#    Opt_Подушки безопасности: водителя  Opt_Количество мест: 6  \
# 0                                   0                       0
# 1                                   0                       0
#
#    Opt_Легкосплавные диски: 13"  Opt_Легкосплавные диски: 22"
# 0                             0                             0
# 1                             0                             0

# %%
#plot car price distribution
sns.distplot(dt['Price_rub'])

# %% [markdown]
# Looks like we have very expensive cars. Max price is higher than 10 mio rub. After exploring such advertisings - such high price is because of bullet proof car body. It does not mentiond in car parameters, such cars has only additional text comment. As we are not interested in buying or selling bulletproof cars such cars would be excluded from future analysis

# %%
#remove bulletproof expensive cars
dt = dt[dt['Price_rub'] < 4 * 10 ** 6]

# %%
dt.describe()
# Out:
#        Advertising_num_days            ID       Price_rub            Views  \
# count           7705.000000  7.705000e+03     7705.000000      7705.000000
# mean              28.778975  1.031632e+09   756479.457625    309622.554705
# std               55.823362  4.102572e+07   498716.667648   1283299.588625
# min                3.000000  2.446310e+06    15000.000000        51.000000
# 25%                6.000000  1.033019e+09   400000.000000      9050.000000
# 50%               16.000000  1.034078e+09   650000.000000     44322.000000
# 75%               30.000000  1.034811e+09   950000.000000    122027.000000
# max             1057.000000  1.035065e+09  3955000.000000  35171156.000000
#
#            Car_age  Autocode_checked  Last_owner_time_years  Warranty_end  \
# count  7705.000000       7705.000000            7705.000000   7705.000000
# mean      7.570149          0.099286               1.697188      0.103491
# std       5.205641          0.299065               0.874227      0.497993
# min       0.000000          0.000000               0.000000      0.000000
# 25%       4.000000          0.000000               1.583333      0.000000
# 50%       7.000000          0.000000               1.583333      0.000000
# 75%      10.000000          0.000000               1.583333      0.000000
# max      36.000000          1.000000               4.916667      9.719570
#
#        Engine_capacity    Engine_hp  Original_car_passport         run_km  \
# count      7705.000000  7705.000000            7705.000000    7705.000000
# mean          2.355911   180.524234               0.963271  117340.462420
# std           0.456197    43.471505               0.188109   82369.974061
# min           1.400000    78.858943               0.000000       0.000000
# 25%           2.000000   150.000000               1.000000   62419.000000
# 50%           2.400000   173.000000               1.000000  107000.000000
# 75%           2.500000   193.000000               1.000000  160000.000000
# max           4.800000   449.000000               1.000000  999999.000000
#
#        Left_steering  is_metallic_color  Opt_Обивка салона: комбинированный  \
# count    7705.000000        7705.000000                         7705.000000
# mean        0.995068           0.348864                            0.076574
# std         0.070058           0.476642                            0.265931
# min         0.000000           0.000000                            0.000000
# 25%         1.000000           0.000000                            0.000000
# 50%         1.000000           0.000000                            0.000000
# 75%         1.000000           1.000000                            0.000000
# max         1.000000           1.000000                            1.000000
#
#        Opt_Цвет салона: темный  Opt_Тонированные стекла  Opt_Ксеноновые фары  \
# count              7705.000000              7705.000000          7705.000000
# mean                  0.698248                 0.595068             0.577028
# std                   0.459048                 0.490911             0.494063
# min                   0.000000                 0.000000             0.000000
# 25%                   0.000000                 0.000000             0.000000
# 50%                   1.000000                 1.000000             1.000000
# 75%                   1.000000                 1.000000             1.000000
# max                   1.000000                 1.000000             1.000000
#
#               Opt_  Opt_Легкосплавные диски: 17"  Opt_Иммобилайзер  \
# count  7705.000000                   7705.000000       7705.000000
# mean      0.215315                      0.215055          0.519663
# std       0.411067                      0.410887          0.499646
# min       0.000000                      0.000000          0.000000
# 25%       0.000000                      0.000000          0.000000
# 50%       0.000000                      0.000000          1.000000
# 75%       0.000000                      0.000000          1.000000
# max       1.000000                      1.000000          1.000000
#
#        Opt_Штатная  Opt_Бортовой компьютер  Opt_Датчик дождя  \
# count  7705.000000             7705.000000       7705.000000
# mean      0.633485                0.721220          0.597923
# std       0.481884                0.448428          0.490349
# min       0.000000                0.000000          0.000000
# 25%       0.000000                0.000000          0.000000
# 50%       1.000000                1.000000          1.000000
# 75%       1.000000                1.000000          1.000000
# max       1.000000                1.000000          1.000000
#
#        Opt_Датчик света  Opt_Круиз-контроль  Opt_Навигационная система  \
# count       7705.000000         7705.000000                7705.000000
# mean           0.611681            0.575860                   0.229591
# std            0.487399            0.494244                   0.420597
# min            0.000000            0.000000                   0.000000
# 25%            0.000000            0.000000                   0.000000
# 50%            1.000000            1.000000                   0.000000
# 75%            1.000000            1.000000                   0.000000
# max            1.000000            1.000000                   1.000000
#
#        Opt_Обогрев зеркал  Opt_Омыватель фар  Opt_Центральный замок  \
# count         7705.000000        7705.000000            7705.000000
# mean             0.767164           0.583907               0.800779
# std              0.422666           0.492941               0.399441
# min              0.000000           0.000000               0.000000
# 25%              1.000000           0.000000               1.000000
# 50%              1.000000           1.000000               1.000000
# 75%              1.000000           1.000000               1.000000
# max              1.000000           1.000000               1.000000
#
#        Opt_Усилитель руля  Opt_Подогрев руля  Opt_Обогрев сидений  \
# count         7705.000000        7705.000000          7705.000000
# mean             0.799740           0.117456             0.748345
# std              0.400221           0.321984             0.433992
# min              0.000000           0.000000             0.000000
# 25%              1.000000           0.000000             0.000000
# 50%              1.000000           0.000000             1.000000
# 75%              1.000000           0.000000             1.000000
# max              1.000000           1.000000             1.000000
#
#        Opt_Количество мест: 5  Opt_Климат: климат-контроль 2-зонный  \
# count             7705.000000                           7705.000000
# mean                 0.235042                              0.575990
# std                  0.424053                              0.494224
# min                  0.000000                              0.000000
# 25%                  0.000000                              0.000000
# 50%                  0.000000                              1.000000
# 75%                  0.000000                              1.000000
# max                  1.000000                              1.000000
#
#        Opt_Электропривод зеркал  Opt_Стеклоподъемники: электро все  \
# count               7705.000000                        7705.000000
# mean                   0.759247                           0.756522
# std                    0.427568                           0.429209
# min                    0.000000                           0.000000
# 25%                    1.000000                           1.000000
# 50%                    1.000000                           1.000000
# 75%                    1.000000                           1.000000
# max                    1.000000                           1.000000
#
#        Opt_Сиденье водителя: электро  Opt_Сиденье пассажира: электро   \
# count                    7705.000000                      7705.000000
# mean                        0.312654                         0.328358
# std                         0.463605                         0.469646
# min                         0.000000                         0.000000
# 25%                         0.000000                         0.000000
# 50%                         0.000000                         0.000000
# 75%                         1.000000                         1.000000
# max                         1.000000                         1.000000
#
#        Opt_Регулировка руля: электро  Opt_Антиблокировочная система (ABS)  \
# count                    7705.000000                          7705.000000
# mean                        0.091888                             0.813887
# std                         0.288887                             0.389223
# min                         0.000000                             0.000000
# 25%                         0.000000                             1.000000
# 50%                         0.000000                             1.000000
# 75%                         0.000000                             1.000000
# max                         1.000000                             1.000000
#
#        Opt_Антипробуксовочная система  Opt_Система курсовой устойчивости  \
# count                     7705.000000                        7705.000000
# mean                         0.669176                           0.636080
# std                          0.470540                           0.481157
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          1.000000                           1.000000
# 75%                          1.000000                           1.000000
# max                          1.000000                           1.000000
#
#        Opt_Подушки безопасности: передние и боковые  Opt_Парктроник  \
# count                                   7705.000000     7705.000000
# mean                                       0.642700        0.536405
# std                                        0.479235        0.498705
# min                                        0.000000        0.000000
# 25%                                        0.000000        0.000000
# 50%                                        1.000000        1.000000
# 75%                                        1.000000        1.000000
# max                                        1.000000        1.000000
#
#             Opt_CD       Opt_TV  Opt_Обивка салона: кожа  Opt_Люк на крыше  \
# count  7705.000000  7705.000000              7705.000000       7705.000000
# mean      0.770409     0.150032                 0.523426          0.158598
# std       0.420597     0.357126                 0.499483          0.365325
# min       0.000000     0.000000                 0.000000          0.000000
# 25%       1.000000     0.000000                 0.000000          0.000000
# 50%       1.000000     0.000000                 1.000000          0.000000
# 75%       1.000000     0.000000                 1.000000          0.000000
# max       1.000000     1.000000                 1.000000          1.000000
#
#        Opt_Легкосплавные диски: 16"  Opt_Обратная связь  \
# count                   7705.000000          7705.00000
# mean                       0.185464             0.16989
# std                        0.388699             0.37556
# min                        0.000000             0.00000
# 25%                        0.000000             0.00000
# 50%                        0.000000             0.00000
# 75%                        0.000000             0.00000
# max                        1.000000             1.00000
#
#        Opt_Дистанционный запуск двигателя  \
# count                         7705.000000
# mean                             0.086957
# std                              0.281790
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Opt_Регулировка руля: в одной плоскости  Opt_Легкосплавные диски: 18"  \
# count                              7705.000000                   7705.000000
# mean                                  0.138222                      0.072550
# std                                   0.345155                      0.259414
# min                                   0.000000                      0.000000
# 25%                                   0.000000                      0.000000
# 50%                                   0.000000                      0.000000
# 75%                                   0.000000                      0.000000
# max                                   1.000000                      1.000000
#
#        Opt_Сиденье водителя: с памятью положения  \
# count                                7705.000000
# mean                                    0.207787
# std                                     0.405750
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Opt_Регулировка руля: в двух плоскостях  Opt_Цвет салона: светлый  \
# count                              7705.000000               7705.000000
# mean                                  0.558728                  0.198702
# std                                   0.496571                  0.399049
# min                                   0.000000                  0.000000
# 25%                                   0.000000                  0.000000
# 50%                                   1.000000                  0.000000
# 75%                                   1.000000                  0.000000
# max                                   1.000000                  1.000000
#
#        Opt_Подушки безопасности: водителя и пассажира  \
# count                                     7705.000000
# mean                                         0.150032
# std                                          0.357126
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Opt_Легкосплавные диски: 12"  Opt_Климат: климат-контроль 1-зонный  \
# count                   7705.000000                           7705.000000
# mean                       0.035302                              0.110058
# std                        0.184553                              0.312983
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        0.000000                              0.000000
# 75%                        0.000000                              0.000000
# max                        1.000000                              1.000000
#
#        Opt_Стеклоподъемники: электро передние  Opt_Сиденье водителя: ручная   \
# count                             7705.000000                    7705.000000
# mean                                 0.058404                       0.223621
# std                                  0.234520                       0.416698
# min                                  0.000000                       0.000000
# 25%                                  0.000000                       0.000000
# 50%                                  0.000000                       0.000000
# 75%                                  0.000000                       0.000000
# max                                  1.000000                       1.000000
#
#        Opt_Сиденье пассажира: ручная   Opt_Обивка салона: велюр  \
# count                     7705.000000               7705.000000
# mean                         0.347826                  0.069176
# std                          0.476311                  0.253769
# min                          0.000000                  0.000000
# 25%                          0.000000                  0.000000
# 50%                          0.000000                  0.000000
# 75%                          1.000000                  0.000000
# max                          1.000000                  1.000000
#
#        Opt_Кассетник  Opt_Климат: климат-контроль 3-зонный  \
# count    7705.000000                           7705.000000
# mean        0.031149                              0.064893
# std         0.173730                              0.246353
# min         0.000000                              0.000000
# 25%         0.000000                              0.000000
# 50%         0.000000                              0.000000
# 75%         0.000000                              0.000000
# max         1.000000                              1.000000
#
#        Opt_Стеклоподъемники: ручные  Opt_Обивка салона: ткань  \
# count                   7705.000000               7705.000000
# mean                       0.065412                  0.240493
# std                        0.247268                  0.427411
# min                        0.000000                  0.000000
# 25%                        0.000000                  0.000000
# 50%                        0.000000                  0.000000
# 75%                        0.000000                  0.000000
# max                        1.000000                  1.000000
#
#        Opt_Сиденье пассажира: с памятью положения  Opt_Количество мест: 2  \
# count                                 7705.000000             7705.000000
# mean                                     0.049578                0.111875
# std                                      0.217086                0.315234
# min                                      0.000000                0.000000
# 25%                                      0.000000                0.000000
# 50%                                      0.000000                0.000000
# 75%                                      0.000000                0.000000
# max                                      1.000000                1.000000
#
#        Opt_Легкосплавные диски: 15"  Opt_Количество мест: 4  \
# count                   7705.000000             7705.000000
# mean                       0.024789                0.043219
# std                        0.155492                0.203362
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        Opt_Легкосплавные диски: 19"  Opt_Сиденье пассажира: ручная по высоте  \
# count                   7705.000000                              7705.000000
# mean                       0.014017                                 0.107073
# std                        0.117568                                 0.309227
# min                        0.000000                                 0.000000
# 25%                        0.000000                                 0.000000
# 50%                        0.000000                                 0.000000
# 75%                        0.000000                                 0.000000
# max                        1.000000                                 1.000000
#
#        Opt_Сиденье водителя: ручная по высоте  Opt_Количество мест: 7  \
# count                             7705.000000             7705.000000
# mean                                 0.137313                0.000649
# std                                  0.344200                0.025467
# min                                  0.000000                0.000000
# 25%                                  0.000000                0.000000
# 50%                                  0.000000                0.000000
# 75%                                  0.000000                0.000000
# max                                  1.000000                1.000000
#
#        Opt_Климат: кондиционер  Opt_Газобаллонное оборудование  \
# count              7705.000000                     7705.000000
# mean                  0.078520                        0.010642
# std                   0.269006                        0.102618
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                   1.000000                        1.000000
#
#        Opt_Легкосплавные диски: 20"  Opt_Легкосплавные диски: 14"  \
# count                   7705.000000                   7705.000000
# mean                       0.001947                      0.000779
# std                        0.044082                      0.027896
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000
#
#        Opt_Подушки безопасности: водителя  Opt_Количество мест: 6  \
# count                         7705.000000             7705.000000
# mean                             0.008436                0.000389
# std                              0.091466                0.019730
# min                              0.000000                0.000000
# 25%                              0.000000                0.000000
# 50%                              0.000000                0.000000
# 75%                              0.000000                0.000000
# max                              1.000000                1.000000
#
#        Opt_Легкосплавные диски: 13"  Opt_Легкосплавные диски: 22"
# count                   7705.000000                   7705.000000
# mean                       0.000130                      0.000130
# std                        0.011392                      0.011392
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000

# %% [markdown]
# suspicious warranty end in 9.7 year from now

# %%
dt[dt['Warranty_end'] > 6]
# Out:
# Empty DataFrame
# Columns: [Advertising_num_days, CarName, ID, Price_rub, Seller, Seller_location, Views, Car_age, Gear_box, Parsing date, Autocode_checked, Owners_N, Last_owner_time_years, Warranty_end, Engine_capacity, Engine_hp, Engine_fuel_type, Body_type, Swap_type, Original_car_passport, Wheel_drive_type, run_km, Left_steering, is_metallic_color, Color, Opt_Обивка салона: комбинированный, Opt_Цвет салона: темный, Opt_Тонированные стекла, Opt_Ксеноновые фары, Opt_, Opt_Легкосплавные диски: 17", Opt_Иммобилайзер, Opt_Штатная, Opt_Бортовой компьютер, Opt_Датчик дождя, Opt_Датчик света, Opt_Круиз-контроль, Opt_Навигационная система, Opt_Обогрев зеркал, Opt_Омыватель фар, Opt_Центральный замок, Opt_Усилитель руля, Opt_Подогрев руля, Opt_Обогрев сидений, Opt_Количество мест: 5, Opt_Климат: климат-контроль 2-зонный, Opt_Электропривод зеркал, Opt_Стеклоподъемники: электро все, Opt_Сиденье водителя: электро, Opt_Сиденье пассажира: электро , Opt_Регулировка руля: электро, Opt_Антиблокировочная система (ABS), Opt_Антипробуксовочная система, Opt_Система курсовой устойчивости, Opt_Подушки безопасности: передние и боковые, Opt_Парктроник, Opt_CD, Opt_TV, Opt_Обивка салона: кожа, Opt_Люк на крыше, Opt_Легкосплавные диски: 16", Opt_Обратная связь, Opt_Дистанционный запуск двигателя, Opt_Регулировка руля: в одной плоскости, Opt_Легкосплавные диски: 18", Opt_Сиденье водителя: с памятью положения, Opt_Регулировка руля: в двух плоскостях, Opt_Цвет салона: светлый, Opt_Подушки безопасности: водителя и пассажира, Opt_Легкосплавные диски: 12", Opt_Климат: климат-контроль 1-зонный, Opt_Стеклоподъемники: электро передние, Opt_Сиденье водителя: ручная , Opt_Сиденье пассажира: ручная , Opt_Обивка салона: велюр, Opt_Кассетник, Opt_Климат: климат-контроль 3-зонный, Opt_Стеклоподъемники: ручные, Opt_Обивка салона: ткань, Opt_Сиденье пассажира: с памятью положения, Opt_Количество мест: 2, Opt_Легкосплавные диски: 15", Opt_Количество мест: 4, Opt_Легкосплавные диски: 19", Opt_Сиденье пассажира: ручная по высоте, Opt_Сиденье водителя: ручная по высоте, Opt_Количество мест: 7, Opt_Климат: кондиционер, Opt_Газобаллонное оборудование, Opt_Легкосплавные диски: 20", Opt_Легкосплавные диски: 14", Opt_Подушки безопасности: водителя, Opt_Количество мест: 6, Opt_Легкосплавные диски: 13", Opt_Легкосплавные диски: 22"]
# Index: []

# %%
#obviously warranty end should be 0 for 8 years old  car
dt.loc[dt['Warranty_end'] > 6, 'Warranty_end'] = 0
# Out:
# C:\Anaconda3\envs\py35\lib\site-packages\pandas\core\indexing.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# num. of days
sns.distplot(dt['Advertising_num_days'], bins =100)
plt.xlim(0, 200)
# Out:
# (0, 200)

# %%
# scatterplot of log(views) vs log(number_of_advertising_days)
# it's clearly have 3 clusters of advertisement

sns.regplot(np.log(dt['Advertising_num_days']),np.log(dt['Views']))

# %%
from pandas.tools.plotting import scatter_matrix
sc_matr = scatter_matrix(dt[['Price_rub','run_km','Car_age','Engine_capacity','Engine_hp','Advertising_num_days',
                             'Views','Last_owner_time_years','Warranty_end']], alpha=0.2, figsize=(12, 12), diagonal='kde')

# %% [markdown]
# From scatter matrix printed above we can see strong relation of car price from
#
# negative:
# 1) Car Age (not linear)
# 2) Car run (not linear)
#
# positive:
# 1) Engine capacity
# 2) Engine horse power (strong heteroscedasticity)
#
# positive not strong:
# 1) Number of advertising days
# 2) Views
# 3) Last owner time
# 4) Time to warranty end

# %% [markdown]
# Let's find explore not linear forms of relation. It is common sense that car price decreses on certain percentage every year. So as it becomes older price decreases for smaller ammount of money. So obvious form of relation for price vs age would be log-linear. Same logic applies for car run.

# %%
sns.regplot((dt['Car_age']),np.log(dt['Price_rub']))

# %%
sns.regplot((dt['run_km']),np.log(dt['Price_rub']))

# %% [markdown]
# engine capacity doen't have high relation to price and price could vary sharply across given capacity. Let's consider multiplicative relation in order to decrease variance and outliers values. Same for Engine horse power.

# %%
sns.regplot(np.log(dt['Engine_capacity']),np.log(dt['Price_rub']))

# %%
sns.regplot(np.log(dt['Engine_hp']),np.log(dt['Price_rub']))

# %% [markdown]
# the chart is not clear whether there are relationship between price vs length of advertisement or number of views. As most of advertisement concentraited  in one area let's check for quadratic form of relation.

# %%
sns.regplot(np.log(dt['Advertising_num_days']) ,np.log(dt['Price_rub']))

# %%
sns.regplot(np.log(dt['Views']) ,np.log(dt['Price_rub']))

# %% [markdown]
# Nice positive relation between last owner time and price

# %%
sns.regplot(np.log(dt['Last_owner_time_years']+1) ,np.log(dt['Price_rub']))

# %% [markdown]
# Active warranty shoud add some value to price, but dummy variable for no warranty shoud be considered

# %%
sns.regplot(np.log(dt['Warranty_end']+1) ,np.log(dt['Price_rub']))

# %% [markdown]
# # Linear Model

# %% [markdown]
# After exploring of basic variables, good start is to build linear moder in order to understand how good or bad we can forecast car price based on few obvious factors. Than it would be useful to compare results of various machine learning techniques with simple linear model forecast.
